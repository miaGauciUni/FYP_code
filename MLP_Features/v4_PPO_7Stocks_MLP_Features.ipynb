# %% [markdown]
# # PPO with MLP - Features

# %%
import numpy as np
import yfinance as yf
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import pandas as pd
import math
import random
import matplotlib.dates as mdates

# %%
tickers = ["AAPL","MSFT","GOOGL","META","AMZN","TSLA","NVDA"]

data = {}
for t in tickers:
    df = yf.download(t, start="2020-01-01", end="2023-01-01").copy()
    closes = df["Close"].astype(np.float32)
    mu, sigma = closes.mean(), closes.std()
    norm = (closes - mu) / sigma

    # Features and their windows are the exact same as the supervised learning 
    # EMA (5‑day)
    ema = closes.ewm(span=5, adjust=False).mean().astype(np.float32)

    # RSI (14‑day)
    delta = closes.diff()
    gain  = delta.clip(lower=0).rolling(14).mean()
    loss  = -delta.clip(upper=0).rolling(14).mean()
    rs    = gain / loss
    rsi   = (100 - 100/(1 + rs)).astype(np.float32)

    # MACD (12‑26)
    ema12 = closes.ewm(span=12, adjust=False).mean()
    ema26 = closes.ewm(span=26, adjust=False).mean()
    macd  = (ema12 - ema26).astype(np.float32)

    # Bollinger Bands (20‑day)
    mbb    = closes.rolling(20).mean()
    mbb_sd = closes.rolling(20).std()
    bb_upper = (mbb + 2*mbb_sd).astype(np.float32)
    bb_lower = (mbb - 2*mbb_sd).astype(np.float32)

    data[t] = {
        "dates":      df.index,
        "raw":        closes.values,
        "norm":       norm.values,
        "ema":        ema.values,
        "rsi":        rsi.values,
        "macd":       macd.values,
        "bb_upper":   bb_upper.values,
        "bb_lower":   bb_lower.values,
    }

raw_prices =    {t: data[t]["raw"]      for t in tickers}
normalized_prices = {t: data[t]["norm"]      for t in tickers}

# dropping any Nan values
for t in tickers:
    # stacking feature columns to detect any NaNs per row
    feat_stack = np.column_stack([
        data[t]["norm"],
        data[t]["ema"],
        data[t]["rsi"],
        data[t]["macd"],
        data[t]["bb_upper"],
        data[t]["bb_lower"],
    ])
    valid_rows = ~np.isnan(feat_stack).any(axis=1)
    start_idx = np.argmax(valid_rows)

    data[t]["dates"]    = data[t]["dates"][start_idx:]
    data[t]["raw"]      = data[t]["raw"][start_idx:]
    data[t]["norm"]     = data[t]["norm"][start_idx:]
    data[t]["ema"]      = data[t]["ema"][start_idx:]
    data[t]["rsi"]      = data[t]["rsi"][start_idx:]
    data[t]["macd"]     = data[t]["macd"][start_idx:]
    data[t]["bb_upper"] = data[t]["bb_upper"][start_idx:]
    data[t]["bb_lower"] = data[t]["bb_lower"][start_idx:]


for t in tickers:
    for feat in ["ema", "rsi", "macd", "bb_upper", "bb_lower"]:
        arr = data[t][feat]
        mu, sigma = arr.mean(), arr.std()
        # overwrite with z‑score normalization
        data[t][feat] = (arr - mu) / sigma

# %% [markdown]
# ### PPO for multiple stocks

# %%
state_dim   = 5  # window size 
feat_dim    = 6   # number of features per timestep
action_dim  = 1   # how many features we have 
hidden_dim  = 64  # hidden layer size 
lr          = 1e-4
gamma       = 0.9
lam         = 0.95
clip_eps    = 0.2
epochs      = 300
batch_size  = 32
l2_lambda   = 1e-4

# build multi‐stock timeseries states with 6 features per timestep
state_window = state_dim
states, next_states, rewards, dones = [], [], [], []

num_days = len(data[tickers[0]]["norm"]) - state_window - 1  # safer to get length from data dict

for day in range(num_days):
    s_day, ns_day, r_day = [], [], []
    
    for t in tickers:
        features = np.column_stack([
            data[t]["norm"],
            data[t]["ema"],
            data[t]["rsi"],
            data[t]["macd"],
            data[t]["bb_upper"],
            data[t]["bb_lower"],
        ])
        
        s_feat = features[day:day+state_window]            # shape: (window, 6)
        ns_feat = features[day+1:day+1+state_window]        # shape: (window, 6)
        reward = (data[t]["norm"][day+state_window+1] - data[t]["norm"][day+state_window]).item()

        s_day.append(s_feat)
        ns_day.append(ns_feat)
        r_day.append(reward)
        
    states.append(s_day)
    next_states.append(ns_day)
    rewards.append(r_day)
    dones.append([0.0] * len(tickers))

# convert to tensors 
states      = torch.tensor(np.array(states),      dtype=torch.float32)
next_states = torch.tensor(np.array(next_states), dtype=torch.float32)
rewards     = torch.tensor(np.array(rewards),     dtype=torch.float32)
dones       = torch.tensor(np.array(dones),       dtype=torch.float32)

# Neural Network 
# initialising weights 
w1      = torch.nn.Parameter(torch.randn(state_dim * feat_dim, hidden_dim) * 0.1, requires_grad=True)
w2a     = torch.nn.Parameter(torch.randn(hidden_dim, action_dim) * 0.1, requires_grad=True)
w2c     = torch.nn.Parameter(torch.randn(hidden_dim, 1)          * 0.1, requires_grad=True)
log_std = torch.nn.Parameter(torch.zeros(action_dim))

# L2 & optimizer
optimizer = torch.optim.Adam([
    {'params': [w1, w2a, w2c], 'weight_decay': l2_lambda},
    {'params': [log_std],       'weight_decay': 0.0},], lr=lr)

# MLP forward
def mlp_forward(x, w1, w2):
    h = F.relu(x @ w1)
    return h @ w2

# Sample actions
# UPDATED: inputs w1, w2a, log_std so they can be accessed by the environment 
def get_action(state, w1, w2a, log_std):
    mean     = mlp_forward(state, w1, w2a)
    std      = log_std.exp()
    dist     = torch.distributions.Normal(mean, std)
    action   = dist.sample()
    log_prob = dist.log_prob(action).sum(axis=-1)
    return action, log_prob

actor_loss_hist = []
logprob_hist = []

# Collect trajectories (days × stocks) 
with torch.no_grad():
    all_actions   = []
    all_log_probs = []
    all_values    = []

    for day in range(len(states)):            # 1) loop over days
        for stock in range(states.size(1)):  # 2) inner loop over 5 stocks
            s = states[day, stock].view(1, -1)
            a, lp = get_action(s, w1, w2a, log_std)
            v     = mlp_forward(s, w1, w2c)

            all_actions  .append(a)
            all_log_probs.append(lp)
            all_values   .append(v)

    # bootstrap final values for each stock
    for stock in range(next_states.size(1)):
        s_final = next_states[-1, stock].view(1, -1)
        all_values.append(mlp_forward(s_final, w1, w2c))

# reshape into tensors
actions   = torch.cat(all_actions).view(len(states), -1, action_dim)
log_probs = torch.stack(all_log_probs).view(len(states), -1)
values    = torch.stack(all_values).view(len(states)+1, states.size(1))

# GAE calculation
advantages = torch.zeros_like(rewards)
for stock in range(states.size(1)):
    last_adv = 0
    for t in reversed(range(len(states))):
        delta    = rewards[t,stock] \
                   + gamma * values[t+1,stock] * (1 - dones[t,stock]) \
                   - values[t,stock]
        last_adv = delta + gamma * lam * (1 - dones[t,stock]) * last_adv
        advantages[t,stock] = last_adv
returns = advantages + values[:-1]

# flatten transitions for PPO
flat_states = states.view(-1, state_dim * feat_dim)
flat_actions = actions.view(-1, action_dim)
flat_lp_old  = log_probs.view(-1)
flat_ret     = returns.view(-1)
flat_adv     = advantages.view(-1)

critic_loss_hist = []
reward_hist = []
entropy_hist = []

# compute number of mini‑batches per epoch
n_trans   = flat_states.size(0)

n_batches = math.ceil(n_trans / batch_size)

# PPO training
for epoch in range(epochs):
    perm = torch.randperm(n_trans)
    epoch_actor_loss  = 0.0
    epoch_critic_loss = 0.0
    epoch_reward      = 0.0
    epoch_entropy     = 0.0
    epoch_logprob     = 0.0
    for batch_idx, start in enumerate(range(0, n_trans, batch_size), start=1):
        idx          = perm[start:start+batch_size]
        state_batch  = flat_states[idx]
        action_batch = flat_actions[idx].unsqueeze(1)
        old_logps_b  = flat_lp_old[idx].detach()
        return_batch = flat_ret[idx].detach()
        adv_batch    = flat_adv[idx].detach()

        # actor
        mean     = mlp_forward(state_batch, w1, w2a)
        std      = log_std.exp()
        dist     = torch.distributions.Normal(mean, std)
        new_lps  = dist.log_prob(action_batch).sum(axis=-1)

        ratio    = (new_lps - old_logps_b).exp()
        clipped  = torch.clamp(ratio, 1 - clip_eps, 1 + clip_eps) * adv_batch
        actor_loss = -torch.min(ratio * adv_batch, clipped).mean()

        # record entropy & log‐prob stats for this batch
        batch_entropy = dist.entropy().sum(axis=-1).mean()       # average entropy over batch
        batch_logprob = new_lps.mean()                          # average log‐prob over batch
        epoch_entropy += batch_entropy.item()
        epoch_logprob += batch_logprob.item()

        # critic
        value_pred  = mlp_forward(state_batch, w1, w2c).squeeze(-1)
        critic_loss = F.mse_loss(value_pred, return_batch)

        loss = actor_loss + 0.5 * critic_loss

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        epoch_actor_loss  += actor_loss.item()
        epoch_critic_loss += critic_loss.item()
        epoch_reward      += return_batch.mean().item()

        # per‑batch print
        print(f"  Epoch {epoch+1}, Batch {batch_idx}/{n_batches} → Batch Loss: {loss.item():.4f}")

    actor_loss_hist .append(epoch_actor_loss  / n_batches)
    critic_loss_hist.append(epoch_critic_loss / n_batches)
    reward_hist     .append(epoch_reward      / n_batches)
    entropy_hist    .append(epoch_entropy     / n_batches)
    logprob_hist    .append(epoch_logprob     / n_batches)
# Out:
#   Epoch 1, Batch 1/160 → Batch Loss: 0.0137
#   Epoch 1, Batch 2/160 → Batch Loss: -0.0228
#   Epoch 1, Batch 3/160 → Batch Loss: -0.0086
#   Epoch 1, Batch 4/160 → Batch Loss: 0.1520
#   Epoch 1, Batch 5/160 → Batch Loss: -0.0296
#   Epoch 1, Batch 6/160 → Batch Loss: 0.1415
#   Epoch 1, Batch 7/160 → Batch Loss: 0.0503
#   Epoch 1, Batch 8/160 → Batch Loss: 0.1422
#   Epoch 1, Batch 9/160 → Batch Loss: 0.0280
#   Epoch 1, Batch 10/160 → Batch Loss: 0.0944
#   Epoch 1, Batch 11/160 → Batch Loss: 0.0396
#   Epoch 1, Batch 12/160 → Batch Loss: 0.0511
#   Epoch 1, Batch 13/160 → Batch Loss: 0.0805
#   Epoch 1, Batch 14/160 → Batch Loss: -0.0601
#   Epoch 1, Batch 15/160 → Batch Loss: 0.0442
#   Epoch 1, Batch 16/160 → Batch Loss: 0.0241
#   Epoch 1, Batch 17/160 → Batch Loss: 0.1417
#   Epoch 1, Batch 18/160 → Batch Loss: 0.1597
#   Epoch 1, Batch 19/160 → Batch Loss: 0.0496
#   Epoch 1, Batch 20/160 → Batch Loss: 0.0696
#   Epoch 1, Batch 21/160 → Batch Loss: 0.1310
#   Epoch 1, Batch 22/160 → Batch Loss: 0.0029
#   Epoch 1, Batch 23/160 → Batch Loss: -0.0229
#   Epoch 1, Batch 24/160 → Batch Loss: 0.0348
#   Epoch 1, Batch 25/160 → Batch Loss: 0.1736
#   Epoch 1, Batch 26/160 → Batch Loss: 0.0977
#   Epoch 1, Batch 27/160 → Batch Loss: 0.0473
#   Epoch 1, Batch 28/160 → Batch Loss: 0.0310
#   Epoch 1, Batch 29/160 → Batch Loss: 0.0887
#   Epoch 1, Batch 30/160 → Batch Loss: 0.0728
#   Epoch 1, Batch 31/160 → Batch Loss: -0.0305
#   Epoch 1, Batch 32/160 → Batch Loss: 0.1132
#   Epoch 1, Batch 33/160 → Batch Loss: 0.1700
#   Epoch 1, Batch 34/160 → Batch Loss: -0.0160
#   Epoch 1, Batch 35/160 → Batch Loss: 0.0416
#   Epoch 1, Batch 36/160 → Batch Loss: 0.1289
#   Epoch 1, Batch 37/160 → Batch Loss: 0.1555
#   Epoch 1, Batch 38/160 → Batch Loss: 0.0973
#   Epoch 1, Batch 39/160 → Batch Loss: 0.0950
#   Epoch 1, Batch 40/160 → Batch Loss: 0.0730
#   Epoch 1, Batch 41/160 → Batch Loss: 0.0348
#   Epoch 1, Batch 42/160 → Batch Loss: 0.1395
#   Epoch 1, Batch 43/160 → Batch Loss: 0.0005
#   Epoch 1, Batch 44/160 → Batch Loss: 0.0410
#   Epoch 1, Batch 45/160 → Batch Loss: 0.0126
#   Epoch 1, Batch 46/160 → Batch Loss: 0.4153
#   Epoch 1, Batch 47/160 → Batch Loss: -0.0175
#   Epoch 1, Batch 48/160 → Batch Loss: 0.1136
#   Epoch 1, Batch 49/160 → Batch Loss: 0.1542
#   Epoch 1, Batch 50/160 → Batch Loss: 0.2738
#   Epoch 1, Batch 51/160 → Batch Loss: 0.1389
#   Epoch 1, Batch 52/160 → Batch Loss: -0.0270
#   Epoch 1, Batch 53/160 → Batch Loss: 4.1210
#   Epoch 1, Batch 54/160 → Batch Loss: 0.1004
#   Epoch 1, Batch 55/160 → Batch Loss: 0.0900
#   Epoch 1, Batch 56/160 → Batch Loss: -0.0253
#   Epoch 1, Batch 57/160 → Batch Loss: 0.1159
#   Epoch 1, Batch 58/160 → Batch Loss: -0.0244
#   Epoch 1, Batch 59/160 → Batch Loss: 14.4517
#   Epoch 1, Batch 60/160 → Batch Loss: -0.0255
#   Epoch 1, Batch 61/160 → Batch Loss: 0.0186
#   Epoch 1, Batch 62/160 → Batch Loss: 0.0034
#   Epoch 1, Batch 63/160 → Batch Loss: 0.0008
#   Epoch 1, Batch 64/160 → Batch Loss: 0.0777
#   Epoch 1, Batch 65/160 → Batch Loss: 0.0396
#   Epoch 1, Batch 66/160 → Batch Loss: 0.0137
#   Epoch 1, Batch 67/160 → Batch Loss: 0.1602
#   Epoch 1, Batch 68/160 → Batch Loss: 0.0650
#   Epoch 1, Batch 69/160 → Batch Loss: 0.9652
#   Epoch 1, Batch 70/160 → Batch Loss: 0.0810
#   Epoch 1, Batch 71/160 → Batch Loss: 0.4251
#   Epoch 1, Batch 72/160 → Batch Loss: 0.1145
#   Epoch 1, Batch 73/160 → Batch Loss: 0.3636
#   Epoch 1, Batch 74/160 → Batch Loss: 0.0045
#   Epoch 1, Batch 75/160 → Batch Loss: -0.0063
#   Epoch 1, Batch 76/160 → Batch Loss: 0.0456
#   Epoch 1, Batch 77/160 → Batch Loss: 0.0454
#   Epoch 1, Batch 78/160 → Batch Loss: 0.5497
#   Epoch 1, Batch 79/160 → Batch Loss: 0.9646
#   Epoch 1, Batch 80/160 → Batch Loss: 0.3268
#   Epoch 1, Batch 81/160 → Batch Loss: 0.0868
#   Epoch 1, Batch 82/160 → Batch Loss: 0.2237
#   Epoch 1, Batch 83/160 → Batch Loss: 0.0234
#   Epoch 1, Batch 84/160 → Batch Loss: -0.0062
#   Epoch 1, Batch 85/160 → Batch Loss: 0.1647
#   Epoch 1, Batch 86/160 → Batch Loss: -0.0231
#   Epoch 1, Batch 87/160 → Batch Loss: 0.0986
#   Epoch 1, Batch 88/160 → Batch Loss: -0.0147
#   Epoch 1, Batch 89/160 → Batch Loss: 0.0358
#   Epoch 1, Batch 90/160 → Batch Loss: 0.0872
#   Epoch 1, Batch 91/160 → Batch Loss: 0.0574
#   Epoch 1, Batch 92/160 → Batch Loss: 0.5246
#   Epoch 1, Batch 93/160 → Batch Loss: 0.1128
#   Epoch 1, Batch 94/160 → Batch Loss: 0.0940
#   Epoch 1, Batch 95/160 → Batch Loss: 0.1356
#   Epoch 1, Batch 96/160 → Batch Loss: 0.2247
#   Epoch 1, Batch 97/160 → Batch Loss: 0.0301
#   Epoch 1, Batch 98/160 → Batch Loss: -0.0065
#   Epoch 1, Batch 99/160 → Batch Loss: -0.0561
#   Epoch 1, Batch 100/160 → Batch Loss: 0.1372
#   Epoch 1, Batch 101/160 → Batch Loss: -0.0316
#   Epoch 1, Batch 102/160 → Batch Loss: -0.0229
#   Epoch 1, Batch 103/160 → Batch Loss: 0.1067
#   Epoch 1, Batch 104/160 → Batch Loss: 0.0104
#   Epoch 1, Batch 105/160 → Batch Loss: 0.8187
#   Epoch 1, Batch 106/160 → Batch Loss: 0.1853
#   Epoch 1, Batch 107/160 → Batch Loss: 0.1222
#   Epoch 1, Batch 108/160 → Batch Loss: 0.0700
#   Epoch 1, Batch 109/160 → Batch Loss: 0.0246
#   Epoch 1, Batch 110/160 → Batch Loss: 0.0765
#   Epoch 1, Batch 111/160 → Batch Loss: 0.0140
#   Epoch 1, Batch 112/160 → Batch Loss: 0.0239
#   Epoch 1, Batch 113/160 → Batch Loss: -0.0046
#   Epoch 1, Batch 114/160 → Batch Loss: 0.0344
#   Epoch 1, Batch 115/160 → Batch Loss: 0.2217
#   Epoch 1, Batch 116/160 → Batch Loss: 0.1080
#   Epoch 1, Batch 117/160 → Batch Loss: 0.0294
#   Epoch 1, Batch 118/160 → Batch Loss: 0.0641
#   Epoch 1, Batch 119/160 → Batch Loss: 0.0293
#   Epoch 1, Batch 120/160 → Batch Loss: 0.3125
#   Epoch 1, Batch 121/160 → Batch Loss: 0.1061
#   Epoch 1, Batch 122/160 → Batch Loss: 0.1004
#   Epoch 1, Batch 123/160 → Batch Loss: 0.0387
#   Epoch 1, Batch 124/160 → Batch Loss: 0.0419
#   Epoch 1, Batch 125/160 → Batch Loss: 0.0573
#   Epoch 1, Batch 126/160 → Batch Loss: 0.2097
#   Epoch 1, Batch 127/160 → Batch Loss: 0.0272
#   Epoch 1, Batch 128/160 → Batch Loss: 0.1228
#   Epoch 1, Batch 129/160 → Batch Loss: 0.3215
#   Epoch 1, Batch 130/160 → Batch Loss: 0.0569
#   Epoch 1, Batch 131/160 → Batch Loss: 0.0277
#   Epoch 1, Batch 132/160 → Batch Loss: -0.0068
#   Epoch 1, Batch 133/160 → Batch Loss: 0.0434
#   Epoch 1, Batch 134/160 → Batch Loss: 0.1978
#   Epoch 1, Batch 135/160 → Batch Loss: -0.0154
#   Epoch 1, Batch 136/160 → Batch Loss: 0.0501
#   Epoch 1, Batch 137/160 → Batch Loss: 0.3631
#   Epoch 1, Batch 138/160 → Batch Loss: -0.0317
#   Epoch 1, Batch 139/160 → Batch Loss: 0.0750
#   Epoch 1, Batch 140/160 → Batch Loss: -0.0384
#   Epoch 1, Batch 141/160 → Batch Loss: 0.0454
#   Epoch 1, Batch 142/160 → Batch Loss: 0.0448
#   Epoch 1, Batch 143/160 → Batch Loss: 0.2452
#   Epoch 1, Batch 144/160 → Batch Loss: 0.0136
#   Epoch 1, Batch 145/160 → Batch Loss: 0.0450
#   Epoch 1, Batch 146/160 → Batch Loss: 0.1591
#   Epoch 1, Batch 147/160 → Batch Loss: -0.0110
#   Epoch 1, Batch 148/160 → Batch Loss: 0.1624
#   Epoch 1, Batch 149/160 → Batch Loss: 0.0267
#   Epoch 1, Batch 150/160 → Batch Loss: 0.0970
#   Epoch 1, Batch 151/160 → Batch Loss: 0.0639
#   Epoch 1, Batch 152/160 → Batch Loss: 0.0436
#   Epoch 1, Batch 153/160 → Batch Loss: 0.0786
#   Epoch 1, Batch 154/160 → Batch Loss: 0.2074
#   Epoch 1, Batch 155/160 → Batch Loss: 0.4745
#   Epoch 1, Batch 156/160 → Batch Loss: 0.0932
#   Epoch 1, Batch 157/160 → Batch Loss: 0.1775
#   Epoch 1, Batch 158/160 → Batch Loss: 0.0069
#   Epoch 1, Batch 159/160 → Batch Loss: -0.0227
#   Epoch 1, Batch 160/160 → Batch Loss: 0.0028
#   Epoch 2, Batch 1/160 → Batch Loss: 0.0094
#   Epoch 2, Batch 2/160 → Batch Loss: -0.0142
#   Epoch 2, Batch 3/160 → Batch Loss: 0.0146
#   Epoch 2, Batch 4/160 → Batch Loss: 0.1363
#   Epoch 2, Batch 5/160 → Batch Loss: -0.0116
#   Epoch 2, Batch 6/160 → Batch Loss: 0.7300
#   Epoch 2, Batch 7/160 → Batch Loss: 0.0040
#   Epoch 2, Batch 8/160 → Batch Loss: -0.0308
#   Epoch 2, Batch 9/160 → Batch Loss: 0.0648
#   Epoch 2, Batch 10/160 → Batch Loss: 0.0166
#   Epoch 2, Batch 11/160 → Batch Loss: -0.0164
#   Epoch 2, Batch 12/160 → Batch Loss: 0.0788
#   Epoch 2, Batch 13/160 → Batch Loss: 0.1159
#   Epoch 2, Batch 14/160 → Batch Loss: 0.0212
#   Epoch 2, Batch 15/160 → Batch Loss: 0.3751
#   Epoch 2, Batch 16/160 → Batch Loss: 0.0706
#   Epoch 2, Batch 17/160 → Batch Loss: 0.1020
#   Epoch 2, Batch 18/160 → Batch Loss: 0.0629
#   Epoch 2, Batch 19/160 → Batch Loss: 0.1152
#   Epoch 2, Batch 20/160 → Batch Loss: 0.0168
#   Epoch 2, Batch 21/160 → Batch Loss: 0.0763
#   Epoch 2, Batch 22/160 → Batch Loss: 0.1640
#   Epoch 2, Batch 23/160 → Batch Loss: 0.1619
#   Epoch 2, Batch 24/160 → Batch Loss: -0.0220
#   Epoch 2, Batch 25/160 → Batch Loss: -0.0284
#   Epoch 2, Batch 26/160 → Batch Loss: 0.1214
#   Epoch 2, Batch 27/160 → Batch Loss: 0.0314
#   Epoch 2, Batch 28/160 → Batch Loss: -0.0072
#   Epoch 2, Batch 29/160 → Batch Loss: 0.9277
#   Epoch 2, Batch 30/160 → Batch Loss: 0.1547
#   Epoch 2, Batch 31/160 → Batch Loss: 0.0266
#   Epoch 2, Batch 32/160 → Batch Loss: 0.0628
#   Epoch 2, Batch 33/160 → Batch Loss: -0.0333
#   Epoch 2, Batch 34/160 → Batch Loss: -0.0177
#   Epoch 2, Batch 35/160 → Batch Loss: 0.0297
#   Epoch 2, Batch 36/160 → Batch Loss: 0.0601
#   Epoch 2, Batch 37/160 → Batch Loss: 0.3008
#   Epoch 2, Batch 38/160 → Batch Loss: 0.0847
#   Epoch 2, Batch 39/160 → Batch Loss: 0.0462
#   Epoch 2, Batch 40/160 → Batch Loss: 0.0688
#   Epoch 2, Batch 41/160 → Batch Loss: 0.0780
#   Epoch 2, Batch 42/160 → Batch Loss: -0.0006
#   Epoch 2, Batch 43/160 → Batch Loss: 0.0914
#   Epoch 2, Batch 44/160 → Batch Loss: 0.3086
#   Epoch 2, Batch 45/160 → Batch Loss: 0.1357
#   Epoch 2, Batch 46/160 → Batch Loss: -0.0610
#   Epoch 2, Batch 47/160 → Batch Loss: -0.0473
#   Epoch 2, Batch 48/160 → Batch Loss: 0.1607
#   Epoch 2, Batch 49/160 → Batch Loss: 0.1751
#   Epoch 2, Batch 50/160 → Batch Loss: -0.0377
#   Epoch 2, Batch 51/160 → Batch Loss: 0.0968
#   Epoch 2, Batch 52/160 → Batch Loss: 0.1595
#   Epoch 2, Batch 53/160 → Batch Loss: 0.2993
#   Epoch 2, Batch 54/160 → Batch Loss: 0.1129
#   Epoch 2, Batch 55/160 → Batch Loss: 0.0431
#   Epoch 2, Batch 56/160 → Batch Loss: 0.4234
#   Epoch 2, Batch 57/160 → Batch Loss: 0.0293
#   Epoch 2, Batch 58/160 → Batch Loss: 0.0203
#   Epoch 2, Batch 59/160 → Batch Loss: 0.0621
#   Epoch 2, Batch 60/160 → Batch Loss: -0.0452
#   Epoch 2, Batch 61/160 → Batch Loss: -0.0175
#   Epoch 2, Batch 62/160 → Batch Loss: 0.0204
#   Epoch 2, Batch 63/160 → Batch Loss: 0.0977
#   Epoch 2, Batch 64/160 → Batch Loss: 0.1450
#   Epoch 2, Batch 65/160 → Batch Loss: 0.3809
#   Epoch 2, Batch 66/160 → Batch Loss: 3.6355
#   Epoch 2, Batch 67/160 → Batch Loss: 0.3169
#   Epoch 2, Batch 68/160 → Batch Loss: 0.1317
#   Epoch 2, Batch 69/160 → Batch Loss: 0.1559
#   Epoch 2, Batch 70/160 → Batch Loss: 0.2670
#   Epoch 2, Batch 71/160 → Batch Loss: 0.1212
#   Epoch 2, Batch 72/160 → Batch Loss: -0.0306
#   Epoch 2, Batch 73/160 → Batch Loss: 14.1419
#   Epoch 2, Batch 74/160 → Batch Loss: 0.1385
#   Epoch 2, Batch 75/160 → Batch Loss: 0.0504
#   Epoch 2, Batch 76/160 → Batch Loss: 0.1048
#   Epoch 2, Batch 77/160 → Batch Loss: -0.0480
#   Epoch 2, Batch 78/160 → Batch Loss: -0.0505
#   Epoch 2, Batch 79/160 → Batch Loss: 0.0487
#   Epoch 2, Batch 80/160 → Batch Loss: 0.0253
#   Epoch 2, Batch 81/160 → Batch Loss: 0.0838
#   Epoch 2, Batch 82/160 → Batch Loss: 0.1377
#   Epoch 2, Batch 83/160 → Batch Loss: 0.0187
#   Epoch 2, Batch 84/160 → Batch Loss: 0.0976
#   Epoch 2, Batch 85/160 → Batch Loss: -0.0094
#   Epoch 2, Batch 86/160 → Batch Loss: 0.0454
#   Epoch 2, Batch 87/160 → Batch Loss: 0.1518
#   Epoch 2, Batch 88/160 → Batch Loss: 0.1284
#   Epoch 2, Batch 89/160 → Batch Loss: 0.1364
#   Epoch 2, Batch 90/160 → Batch Loss: -0.0233
#   Epoch 2, Batch 91/160 → Batch Loss: 0.0379
#   Epoch 2, Batch 92/160 → Batch Loss: 0.4077
#   Epoch 2, Batch 93/160 → Batch Loss: 0.2301
#   Epoch 2, Batch 94/160 → Batch Loss: 0.1387
#   Epoch 2, Batch 95/160 → Batch Loss: 0.0372
#   Epoch 2, Batch 96/160 → Batch Loss: 0.0667
#   Epoch 2, Batch 97/160 → Batch Loss: 0.0645
#   Epoch 2, Batch 98/160 → Batch Loss: 0.0784
#   Epoch 2, Batch 99/160 → Batch Loss: 0.0027
#   Epoch 2, Batch 100/160 → Batch Loss: 0.1374
#   Epoch 2, Batch 101/160 → Batch Loss: 0.1077
#   Epoch 2, Batch 102/160 → Batch Loss: 0.1547
#   Epoch 2, Batch 103/160 → Batch Loss: -0.0425
#   Epoch 2, Batch 104/160 → Batch Loss: 0.0250
#   Epoch 2, Batch 105/160 → Batch Loss: 0.0777
#   Epoch 2, Batch 106/160 → Batch Loss: 0.0145
#   Epoch 2, Batch 107/160 → Batch Loss: 0.1196
#   Epoch 2, Batch 108/160 → Batch Loss: 0.0124
#   Epoch 2, Batch 109/160 → Batch Loss: 0.0671
#   Epoch 2, Batch 110/160 → Batch Loss: 0.8732
#   Epoch 2, Batch 111/160 → Batch Loss: 0.0650
#   Epoch 2, Batch 112/160 → Batch Loss: -0.0114
#   Epoch 2, Batch 113/160 → Batch Loss: 0.0792
#   Epoch 2, Batch 114/160 → Batch Loss: 0.0640
#   Epoch 2, Batch 115/160 → Batch Loss: 0.0026
#   Epoch 2, Batch 116/160 → Batch Loss: 0.0225
#   Epoch 2, Batch 117/160 → Batch Loss: 0.0998
#   Epoch 2, Batch 118/160 → Batch Loss: -0.0236
#   Epoch 2, Batch 119/160 → Batch Loss: 0.0233
#   Epoch 2, Batch 120/160 → Batch Loss: 0.0502
#   Epoch 2, Batch 121/160 → Batch Loss: 0.0851
#   Epoch 2, Batch 122/160 → Batch Loss: 0.1056
#   Epoch 2, Batch 123/160 → Batch Loss: -0.0316
#   Epoch 2, Batch 124/160 → Batch Loss: 0.0291
#   Epoch 2, Batch 125/160 → Batch Loss: 0.6506
#   Epoch 2, Batch 126/160 → Batch Loss: 0.0239
#   Epoch 2, Batch 127/160 → Batch Loss: 0.0779
#   Epoch 2, Batch 128/160 → Batch Loss: 0.0499
#   Epoch 2, Batch 129/160 → Batch Loss: 0.0115
#   Epoch 2, Batch 130/160 → Batch Loss: 0.0571
#   Epoch 2, Batch 131/160 → Batch Loss: -0.0119
#   Epoch 2, Batch 132/160 → Batch Loss: 0.0409
#   Epoch 2, Batch 133/160 → Batch Loss: 0.1152
#   Epoch 2, Batch 134/160 → Batch Loss: 0.0430
#   Epoch 2, Batch 135/160 → Batch Loss: 0.2435
#   Epoch 2, Batch 136/160 → Batch Loss: 0.0866
#   Epoch 2, Batch 137/160 → Batch Loss: 0.0205
#   Epoch 2, Batch 138/160 → Batch Loss: -0.0167
#   Epoch 2, Batch 139/160 → Batch Loss: 0.0876
#   Epoch 2, Batch 140/160 → Batch Loss: 0.1123
#   Epoch 2, Batch 141/160 → Batch Loss: 0.0079
#   Epoch 2, Batch 142/160 → Batch Loss: 0.0607
#   Epoch 2, Batch 143/160 → Batch Loss: 0.1839
#   Epoch 2, Batch 144/160 → Batch Loss: 0.0723
#   Epoch 2, Batch 145/160 → Batch Loss: 0.2371
#   Epoch 2, Batch 146/160 → Batch Loss: -0.0138
#   Epoch 2, Batch 147/160 → Batch Loss: 0.0500
#   Epoch 2, Batch 148/160 → Batch Loss: 0.0148
#   Epoch 2, Batch 149/160 → Batch Loss: 0.1307
#   Epoch 2, Batch 150/160 → Batch Loss: 0.1286
#   Epoch 2, Batch 151/160 → Batch Loss: 0.0894
#   Epoch 2, Batch 152/160 → Batch Loss: 0.0713
#   Epoch 2, Batch 153/160 → Batch Loss: 0.1219
#   Epoch 2, Batch 154/160 → Batch Loss: 0.5163
#   Epoch 2, Batch 155/160 → Batch Loss: 0.0418
#   Epoch 2, Batch 156/160 → Batch Loss: 0.0556
#   Epoch 2, Batch 157/160 → Batch Loss: 0.0489
#   Epoch 2, Batch 158/160 → Batch Loss: 0.0159
#   Epoch 2, Batch 159/160 → Batch Loss: 0.5961
#   Epoch 2, Batch 160/160 → Batch Loss: -0.0642
#   Epoch 3, Batch 1/160 → Batch Loss: 0.0407
#   Epoch 3, Batch 2/160 → Batch Loss: -0.0442
#   Epoch 3, Batch 3/160 → Batch Loss: 0.0760
#   Epoch 3, Batch 4/160 → Batch Loss: 0.1679
#   Epoch 3, Batch 5/160 → Batch Loss: 0.0432
#   Epoch 3, Batch 6/160 → Batch Loss: 0.0183
#   Epoch 3, Batch 7/160 → Batch Loss: 0.0037
#   Epoch 3, Batch 8/160 → Batch Loss: 0.0446
#   Epoch 3, Batch 9/160 → Batch Loss: 0.0330
#   Epoch 3, Batch 10/160 → Batch Loss: 0.0361
#   Epoch 3, Batch 11/160 → Batch Loss: 0.0253
#   Epoch 3, Batch 12/160 → Batch Loss: 0.0622
#   Epoch 3, Batch 13/160 → Batch Loss: 0.0596
#   Epoch 3, Batch 14/160 → Batch Loss: 0.0198
#   Epoch 3, Batch 15/160 → Batch Loss: 0.1051
#   Epoch 3, Batch 16/160 → Batch Loss: 0.1063
#   Epoch 3, Batch 17/160 → Batch Loss: 0.0328
#   Epoch 3, Batch 18/160 → Batch Loss: 0.0088
#   Epoch 3, Batch 19/160 → Batch Loss: 0.3765
#   Epoch 3, Batch 20/160 → Batch Loss: -0.0060
#   Epoch 3, Batch 21/160 → Batch Loss: 0.0787
#   Epoch 3, Batch 22/160 → Batch Loss: 0.1432
#   Epoch 3, Batch 23/160 → Batch Loss: -0.0293
#   Epoch 3, Batch 24/160 → Batch Loss: 0.0115
#   Epoch 3, Batch 25/160 → Batch Loss: 0.0223
#   Epoch 3, Batch 26/160 → Batch Loss: 0.0347
#   Epoch 3, Batch 27/160 → Batch Loss: 0.0740
#   Epoch 3, Batch 28/160 → Batch Loss: 0.0132
#   Epoch 3, Batch 29/160 → Batch Loss: 0.0551
#   Epoch 3, Batch 30/160 → Batch Loss: 0.0694
#   Epoch 3, Batch 31/160 → Batch Loss: 0.1333
#   Epoch 3, Batch 32/160 → Batch Loss: 0.0472
#   Epoch 3, Batch 33/160 → Batch Loss: -0.0211
#   Epoch 3, Batch 34/160 → Batch Loss: 0.0881
#   Epoch 3, Batch 35/160 → Batch Loss: 0.1332
#   Epoch 3, Batch 36/160 → Batch Loss: 3.7518
#   Epoch 3, Batch 37/160 → Batch Loss: 0.0196
#   Epoch 3, Batch 38/160 → Batch Loss: 0.0122
#   Epoch 3, Batch 39/160 → Batch Loss: 0.0143
#   Epoch 3, Batch 40/160 → Batch Loss: 0.0300
#   Epoch 3, Batch 41/160 → Batch Loss: 0.7820
#   Epoch 3, Batch 42/160 → Batch Loss: 15.7164
#   Epoch 3, Batch 43/160 → Batch Loss: 0.0453
#   Epoch 3, Batch 44/160 → Batch Loss: 0.0368
#   Epoch 3, Batch 45/160 → Batch Loss: 0.0181
#   Epoch 3, Batch 46/160 → Batch Loss: -0.0082
#   Epoch 3, Batch 47/160 → Batch Loss: 0.0115
#   Epoch 3, Batch 48/160 → Batch Loss: -0.0100
#   Epoch 3, Batch 49/160 → Batch Loss: -0.0306
#   Epoch 3, Batch 50/160 → Batch Loss: 0.1549
#   Epoch 3, Batch 51/160 → Batch Loss: 0.0024
#   Epoch 3, Batch 52/160 → Batch Loss: -0.0756
#   Epoch 3, Batch 53/160 → Batch Loss: -0.0040
#   Epoch 3, Batch 54/160 → Batch Loss: -0.0492
#   Epoch 3, Batch 55/160 → Batch Loss: 0.0476
#   Epoch 3, Batch 56/160 → Batch Loss: 0.0413
#   Epoch 3, Batch 57/160 → Batch Loss: 0.5908
#   Epoch 3, Batch 58/160 → Batch Loss: 0.0232
#   Epoch 3, Batch 59/160 → Batch Loss: -0.0047
#   Epoch 3, Batch 60/160 → Batch Loss: 0.0100
#   Epoch 3, Batch 61/160 → Batch Loss: -0.0246
#   Epoch 3, Batch 62/160 → Batch Loss: 0.1368
#   Epoch 3, Batch 63/160 → Batch Loss: 0.0557
#   Epoch 3, Batch 64/160 → Batch Loss: 0.0942
#   Epoch 3, Batch 65/160 → Batch Loss: 0.0152
#   Epoch 3, Batch 66/160 → Batch Loss: 0.0678
#   Epoch 3, Batch 67/160 → Batch Loss: 0.0464
#   Epoch 3, Batch 68/160 → Batch Loss: 0.0380
#   Epoch 3, Batch 69/160 → Batch Loss: 0.0707
#   Epoch 3, Batch 70/160 → Batch Loss: 0.0786
#   Epoch 3, Batch 71/160 → Batch Loss: 0.1138
#   Epoch 3, Batch 72/160 → Batch Loss: 0.1080
#   Epoch 3, Batch 73/160 → Batch Loss: 0.2373
#   Epoch 3, Batch 74/160 → Batch Loss: 0.3029
#   Epoch 3, Batch 75/160 → Batch Loss: 0.0380
#   Epoch 3, Batch 76/160 → Batch Loss: 0.4302
#   Epoch 3, Batch 77/160 → Batch Loss: 0.0493
#   Epoch 3, Batch 78/160 → Batch Loss: 0.0492
#   Epoch 3, Batch 79/160 → Batch Loss: 0.4266
#   Epoch 3, Batch 80/160 → Batch Loss: 0.1523
#   Epoch 3, Batch 81/160 → Batch Loss: 0.8371
#   Epoch 3, Batch 82/160 → Batch Loss: -0.0011
#   Epoch 3, Batch 83/160 → Batch Loss: 0.0832
#   Epoch 3, Batch 84/160 → Batch Loss: 0.0163
#   Epoch 3, Batch 85/160 → Batch Loss: 0.1232
#   Epoch 3, Batch 86/160 → Batch Loss: 0.9146
#   Epoch 3, Batch 87/160 → Batch Loss: 0.1639
#   Epoch 3, Batch 88/160 → Batch Loss: 0.0486
#   Epoch 3, Batch 89/160 → Batch Loss: 0.0100
#   Epoch 3, Batch 90/160 → Batch Loss: 0.0339
#   Epoch 3, Batch 91/160 → Batch Loss: 0.0444
#   Epoch 3, Batch 92/160 → Batch Loss: -0.0526
#   Epoch 3, Batch 93/160 → Batch Loss: -0.0787
#   Epoch 3, Batch 94/160 → Batch Loss: 0.0921
#   Epoch 3, Batch 95/160 → Batch Loss: 0.0399
#   Epoch 3, Batch 96/160 → Batch Loss: 0.0639
#   Epoch 3, Batch 97/160 → Batch Loss: 0.0162
#   Epoch 3, Batch 98/160 → Batch Loss: 0.0334
#   Epoch 3, Batch 99/160 → Batch Loss: 0.1434
#   Epoch 3, Batch 100/160 → Batch Loss: -0.0007
#   Epoch 3, Batch 101/160 → Batch Loss: -0.0758
#   Epoch 3, Batch 102/160 → Batch Loss: 0.2421
#   Epoch 3, Batch 103/160 → Batch Loss: 0.3831
#   Epoch 3, Batch 104/160 → Batch Loss: 0.3764
#   Epoch 3, Batch 105/160 → Batch Loss: -0.0019
#   Epoch 3, Batch 106/160 → Batch Loss: 0.1926
#   Epoch 3, Batch 107/160 → Batch Loss: 0.1211
#   Epoch 3, Batch 108/160 → Batch Loss: -0.0220
#   Epoch 3, Batch 109/160 → Batch Loss: 0.0561
#   Epoch 3, Batch 110/160 → Batch Loss: 0.0569
#   Epoch 3, Batch 111/160 → Batch Loss: 0.0617
#   Epoch 3, Batch 112/160 → Batch Loss: -0.0547
#   Epoch 3, Batch 113/160 → Batch Loss: 0.1559
#   Epoch 3, Batch 114/160 → Batch Loss: 0.0267
#   Epoch 3, Batch 115/160 → Batch Loss: 0.1403
#   Epoch 3, Batch 116/160 → Batch Loss: 0.0674
#   Epoch 3, Batch 117/160 → Batch Loss: -0.0161
#   Epoch 3, Batch 118/160 → Batch Loss: 0.0777
#   Epoch 3, Batch 119/160 → Batch Loss: 0.0204
#   Epoch 3, Batch 120/160 → Batch Loss: 0.0910
#   Epoch 3, Batch 121/160 → Batch Loss: 0.0156
#   Epoch 3, Batch 122/160 → Batch Loss: 0.1911
#   Epoch 3, Batch 123/160 → Batch Loss: 0.0672
#   Epoch 3, Batch 124/160 → Batch Loss: 0.1145
#   Epoch 3, Batch 125/160 → Batch Loss: 0.1233
#   Epoch 3, Batch 126/160 → Batch Loss: 0.1706
#   Epoch 3, Batch 127/160 → Batch Loss: 0.0300
#   Epoch 3, Batch 128/160 → Batch Loss: 0.0875
#   Epoch 3, Batch 129/160 → Batch Loss: 0.0895
#   Epoch 3, Batch 130/160 → Batch Loss: 0.0936
#   Epoch 3, Batch 131/160 → Batch Loss: 0.0949
#   Epoch 3, Batch 132/160 → Batch Loss: 0.5391
#   Epoch 3, Batch 133/160 → Batch Loss: 0.0432
#   Epoch 3, Batch 134/160 → Batch Loss: 0.0078
#   Epoch 3, Batch 135/160 → Batch Loss: 0.0111
#   Epoch 3, Batch 136/160 → Batch Loss: 0.0420
#   Epoch 3, Batch 137/160 → Batch Loss: 0.0355
#   Epoch 3, Batch 138/160 → Batch Loss: 0.2494
#   Epoch 3, Batch 139/160 → Batch Loss: 0.8445
#   Epoch 3, Batch 140/160 → Batch Loss: 0.0325
#   Epoch 3, Batch 141/160 → Batch Loss: 0.0710
#   Epoch 3, Batch 142/160 → Batch Loss: -0.0116
#   Epoch 3, Batch 143/160 → Batch Loss: 0.2005
#   Epoch 3, Batch 144/160 → Batch Loss: 0.0667
#   Epoch 3, Batch 145/160 → Batch Loss: 0.0322
#   Epoch 3, Batch 146/160 → Batch Loss: -0.0231
#   Epoch 3, Batch 147/160 → Batch Loss: 0.0672
#   Epoch 3, Batch 148/160 → Batch Loss: 0.3390
#   Epoch 3, Batch 149/160 → Batch Loss: -0.0040
#   Epoch 3, Batch 150/160 → Batch Loss: 0.0228
#   Epoch 3, Batch 151/160 → Batch Loss: 0.1028
#   Epoch 3, Batch 152/160 → Batch Loss: 0.0524
#   Epoch 3, Batch 153/160 → Batch Loss: 0.2014
#   Epoch 3, Batch 154/160 → Batch Loss: 0.1151
#   Epoch 3, Batch 155/160 → Batch Loss: 0.0540
#   Epoch 3, Batch 156/160 → Batch Loss: 0.0327
#   Epoch 3, Batch 157/160 → Batch Loss: 0.0625
#   Epoch 3, Batch 158/160 → Batch Loss: 0.0914
#   Epoch 3, Batch 159/160 → Batch Loss: 0.1437
#   Epoch 3, Batch 160/160 → Batch Loss: 0.0214
#   Epoch 4, Batch 1/160 → Batch Loss: 0.3994
#   Epoch 4, Batch 2/160 → Batch Loss: 0.0156
#   Epoch 4, Batch 3/160 → Batch Loss: 0.0149
#   Epoch 4, Batch 4/160 → Batch Loss: 0.1528
#   Epoch 4, Batch 5/160 → Batch Loss: 0.1330
#   Epoch 4, Batch 6/160 → Batch Loss: 0.2131
#   Epoch 4, Batch 7/160 → Batch Loss: 0.0758
#   Epoch 4, Batch 8/160 → Batch Loss: 0.1258
#   Epoch 4, Batch 9/160 → Batch Loss: 0.0393
#   Epoch 4, Batch 10/160 → Batch Loss: 0.0096
#   Epoch 4, Batch 11/160 → Batch Loss: 0.0387
#   Epoch 4, Batch 12/160 → Batch Loss: 0.0673
#   Epoch 4, Batch 13/160 → Batch Loss: 0.1335
#   Epoch 4, Batch 14/160 → Batch Loss: 0.2899
#   Epoch 4, Batch 15/160 → Batch Loss: 0.0208
#   Epoch 4, Batch 16/160 → Batch Loss: 0.1029
#   Epoch 4, Batch 17/160 → Batch Loss: 0.0234
#   Epoch 4, Batch 18/160 → Batch Loss: 0.1453
#   Epoch 4, Batch 19/160 → Batch Loss: 0.0187
#   Epoch 4, Batch 20/160 → Batch Loss: 0.0873
#   Epoch 4, Batch 21/160 → Batch Loss: -0.0125
#   Epoch 4, Batch 22/160 → Batch Loss: 0.0603
#   Epoch 4, Batch 23/160 → Batch Loss: 0.0824
#   Epoch 4, Batch 24/160 → Batch Loss: 0.0730
#   Epoch 4, Batch 25/160 → Batch Loss: -0.0587
#   Epoch 4, Batch 26/160 → Batch Loss: 0.9466
#   Epoch 4, Batch 27/160 → Batch Loss: 0.0321
#   Epoch 4, Batch 28/160 → Batch Loss: 0.0354
#   Epoch 4, Batch 29/160 → Batch Loss: 0.0160
#   Epoch 4, Batch 30/160 → Batch Loss: 0.0122
#   Epoch 4, Batch 31/160 → Batch Loss: -0.0063
#   Epoch 4, Batch 32/160 → Batch Loss: 0.0632
#   Epoch 4, Batch 33/160 → Batch Loss: 0.9467
#   Epoch 4, Batch 34/160 → Batch Loss: -0.0009
#   Epoch 4, Batch 35/160 → Batch Loss: 0.0472
#   Epoch 4, Batch 36/160 → Batch Loss: 0.1061
#   Epoch 4, Batch 37/160 → Batch Loss: 0.3272
#   Epoch 4, Batch 38/160 → Batch Loss: 0.0097
#   Epoch 4, Batch 39/160 → Batch Loss: 0.0961
#   Epoch 4, Batch 40/160 → Batch Loss: 0.0547
#   Epoch 4, Batch 41/160 → Batch Loss: 0.1738
#   Epoch 4, Batch 42/160 → Batch Loss: 0.2738
#   Epoch 4, Batch 43/160 → Batch Loss: -0.0347
#   Epoch 4, Batch 44/160 → Batch Loss: 0.0170
#   Epoch 4, Batch 45/160 → Batch Loss: 0.0491
#   Epoch 4, Batch 46/160 → Batch Loss: 0.0704
#   Epoch 4, Batch 47/160 → Batch Loss: 0.0190
#   Epoch 4, Batch 48/160 → Batch Loss: 0.0355
#   Epoch 4, Batch 49/160 → Batch Loss: 1.1559
#   Epoch 4, Batch 50/160 → Batch Loss: 0.0751
#   Epoch 4, Batch 51/160 → Batch Loss: 0.1188
#   Epoch 4, Batch 52/160 → Batch Loss: 0.0163
#   Epoch 4, Batch 53/160 → Batch Loss: 0.0897
#   Epoch 4, Batch 54/160 → Batch Loss: 0.0559
#   Epoch 4, Batch 55/160 → Batch Loss: 0.0758
#   Epoch 4, Batch 56/160 → Batch Loss: 0.1731
#   Epoch 4, Batch 57/160 → Batch Loss: -0.0321
#   Epoch 4, Batch 58/160 → Batch Loss: -0.0298
#   Epoch 4, Batch 59/160 → Batch Loss: 0.1313
#   Epoch 4, Batch 60/160 → Batch Loss: -0.0101
#   Epoch 4, Batch 61/160 → Batch Loss: 0.0146
#   Epoch 4, Batch 62/160 → Batch Loss: 0.5152
#   Epoch 4, Batch 63/160 → Batch Loss: 15.2357
#   Epoch 4, Batch 64/160 → Batch Loss: 0.0830
#   Epoch 4, Batch 65/160 → Batch Loss: 0.0869
#   Epoch 4, Batch 66/160 → Batch Loss: 0.1159
#   Epoch 4, Batch 67/160 → Batch Loss: -0.0405
#   Epoch 4, Batch 68/160 → Batch Loss: 0.9883
#   Epoch 4, Batch 69/160 → Batch Loss: 0.0290
#   Epoch 4, Batch 70/160 → Batch Loss: 0.0548
#   Epoch 4, Batch 71/160 → Batch Loss: -0.0023
#   Epoch 4, Batch 72/160 → Batch Loss: 0.0692
#   Epoch 4, Batch 73/160 → Batch Loss: 0.1382
#   Epoch 4, Batch 74/160 → Batch Loss: 0.1224
#   Epoch 4, Batch 75/160 → Batch Loss: -0.1114
#   Epoch 4, Batch 76/160 → Batch Loss: 0.1688
#   Epoch 4, Batch 77/160 → Batch Loss: 0.2152
#   Epoch 4, Batch 78/160 → Batch Loss: 0.2116
#   Epoch 4, Batch 79/160 → Batch Loss: 0.0438
#   Epoch 4, Batch 80/160 → Batch Loss: -0.0106
#   Epoch 4, Batch 81/160 → Batch Loss: 0.0374
#   Epoch 4, Batch 82/160 → Batch Loss: 0.0866
#   Epoch 4, Batch 83/160 → Batch Loss: 0.2909
#   Epoch 4, Batch 84/160 → Batch Loss: 0.1116
#   Epoch 4, Batch 85/160 → Batch Loss: 0.0107
#   Epoch 4, Batch 86/160 → Batch Loss: 0.3208
#   Epoch 4, Batch 87/160 → Batch Loss: 0.0119
#   Epoch 4, Batch 88/160 → Batch Loss: 0.1343
#   Epoch 4, Batch 89/160 → Batch Loss: 0.1014
#   Epoch 4, Batch 90/160 → Batch Loss: 0.0205
#   Epoch 4, Batch 91/160 → Batch Loss: -0.0024
#   Epoch 4, Batch 92/160 → Batch Loss: 0.0109
#   Epoch 4, Batch 93/160 → Batch Loss: 0.1275
#   Epoch 4, Batch 94/160 → Batch Loss: -0.0230
#   Epoch 4, Batch 95/160 → Batch Loss: 0.0884
#   Epoch 4, Batch 96/160 → Batch Loss: 0.0627
#   Epoch 4, Batch 97/160 → Batch Loss: 0.3442
#   Epoch 4, Batch 98/160 → Batch Loss: -0.0196
#   Epoch 4, Batch 99/160 → Batch Loss: 0.0751
#   Epoch 4, Batch 100/160 → Batch Loss: -0.0253
#   Epoch 4, Batch 101/160 → Batch Loss: 0.1167
#   Epoch 4, Batch 102/160 → Batch Loss: -0.0169
#   Epoch 4, Batch 103/160 → Batch Loss: -0.0107
#   Epoch 4, Batch 104/160 → Batch Loss: 3.6056
#   Epoch 4, Batch 105/160 → Batch Loss: 0.0712
#   Epoch 4, Batch 106/160 → Batch Loss: 0.0926
#   Epoch 4, Batch 107/160 → Batch Loss: -0.0137
#   Epoch 4, Batch 108/160 → Batch Loss: -0.0227
#   Epoch 4, Batch 109/160 → Batch Loss: 0.0111
#   Epoch 4, Batch 110/160 → Batch Loss: 0.1824
#   Epoch 4, Batch 111/160 → Batch Loss: -0.0879
#   Epoch 4, Batch 112/160 → Batch Loss: 0.0544
#   Epoch 4, Batch 113/160 → Batch Loss: -0.0616
#   Epoch 4, Batch 114/160 → Batch Loss: 0.0324
#   Epoch 4, Batch 115/160 → Batch Loss: 0.0364
#   Epoch 4, Batch 116/160 → Batch Loss: 0.0124
#   Epoch 4, Batch 117/160 → Batch Loss: 0.5100
#   Epoch 4, Batch 118/160 → Batch Loss: 0.0492
#   Epoch 4, Batch 119/160 → Batch Loss: 0.0413
#   Epoch 4, Batch 120/160 → Batch Loss: 0.1230
#   Epoch 4, Batch 121/160 → Batch Loss: 0.0851
#   Epoch 4, Batch 122/160 → Batch Loss: -0.0562
#   Epoch 4, Batch 123/160 → Batch Loss: 0.0397
#   Epoch 4, Batch 124/160 → Batch Loss: 0.0143
#   Epoch 4, Batch 125/160 → Batch Loss: 0.1079
#   Epoch 4, Batch 126/160 → Batch Loss: 0.0798
#   Epoch 4, Batch 127/160 → Batch Loss: 0.0036
#   Epoch 4, Batch 128/160 → Batch Loss: 0.1346
#   Epoch 4, Batch 129/160 → Batch Loss: 0.0631
#   Epoch 4, Batch 130/160 → Batch Loss: 0.0178
#   Epoch 4, Batch 131/160 → Batch Loss: 0.0161
#   Epoch 4, Batch 132/160 → Batch Loss: 0.0190
#   Epoch 4, Batch 133/160 → Batch Loss: 0.0482
#   Epoch 4, Batch 134/160 → Batch Loss: -0.0006
#   Epoch 4, Batch 135/160 → Batch Loss: 0.0660
#   Epoch 4, Batch 136/160 → Batch Loss: 0.0949
#   Epoch 4, Batch 137/160 → Batch Loss: 0.0847
#   Epoch 4, Batch 138/160 → Batch Loss: -0.0342
#   Epoch 4, Batch 139/160 → Batch Loss: 0.1418
#   Epoch 4, Batch 140/160 → Batch Loss: 0.1284
#   Epoch 4, Batch 141/160 → Batch Loss: -0.0600
#   Epoch 4, Batch 142/160 → Batch Loss: -0.0303
#   Epoch 4, Batch 143/160 → Batch Loss: 0.1113
#   Epoch 4, Batch 144/160 → Batch Loss: 0.0277
#   Epoch 4, Batch 145/160 → Batch Loss: 0.0228
#   Epoch 4, Batch 146/160 → Batch Loss: 0.0771
#   Epoch 4, Batch 147/160 → Batch Loss: 0.1049
#   Epoch 4, Batch 148/160 → Batch Loss: -0.0009
#   Epoch 4, Batch 149/160 → Batch Loss: -0.0227
#   Epoch 4, Batch 150/160 → Batch Loss: -0.0375
#   Epoch 4, Batch 151/160 → Batch Loss: -0.0096
#   Epoch 4, Batch 152/160 → Batch Loss: 0.1494
#   Epoch 4, Batch 153/160 → Batch Loss: -0.0189
#   Epoch 4, Batch 154/160 → Batch Loss: 0.1102
#   Epoch 4, Batch 155/160 → Batch Loss: 0.0274
#   Epoch 4, Batch 156/160 → Batch Loss: 0.0126
#   Epoch 4, Batch 157/160 → Batch Loss: 0.0092
#   Epoch 4, Batch 158/160 → Batch Loss: 0.1312
#   Epoch 4, Batch 159/160 → Batch Loss: -0.0325
#   Epoch 4, Batch 160/160 → Batch Loss: 0.1237
#   Epoch 5, Batch 1/160 → Batch Loss: 0.0278
#   Epoch 5, Batch 2/160 → Batch Loss: 0.0470
#   Epoch 5, Batch 3/160 → Batch Loss: 0.0407
#   Epoch 5, Batch 4/160 → Batch Loss: 0.0204
#   Epoch 5, Batch 5/160 → Batch Loss: 0.1335
#   Epoch 5, Batch 6/160 → Batch Loss: 0.0362
#   Epoch 5, Batch 7/160 → Batch Loss: 0.0810
#   Epoch 5, Batch 8/160 → Batch Loss: 0.0921
#   Epoch 5, Batch 9/160 → Batch Loss: 0.0110
#   Epoch 5, Batch 10/160 → Batch Loss: 0.1232
#   Epoch 5, Batch 11/160 → Batch Loss: 0.0522
#   Epoch 5, Batch 12/160 → Batch Loss: 0.0943
#   Epoch 5, Batch 13/160 → Batch Loss: 0.1081
#   Epoch 5, Batch 14/160 → Batch Loss: 0.7207
#   Epoch 5, Batch 15/160 → Batch Loss: 0.0460
#   Epoch 5, Batch 16/160 → Batch Loss: 0.0598
#   Epoch 5, Batch 17/160 → Batch Loss: -0.0151
#   Epoch 5, Batch 18/160 → Batch Loss: 0.1454
#   Epoch 5, Batch 19/160 → Batch Loss: 0.0252
#   Epoch 5, Batch 20/160 → Batch Loss: -0.0147
#   Epoch 5, Batch 21/160 → Batch Loss: -0.0290
#   Epoch 5, Batch 22/160 → Batch Loss: 0.0482
#   Epoch 5, Batch 23/160 → Batch Loss: 0.1071
#   Epoch 5, Batch 24/160 → Batch Loss: 0.0048
#   Epoch 5, Batch 25/160 → Batch Loss: 0.0223
#   Epoch 5, Batch 26/160 → Batch Loss: 0.0802
#   Epoch 5, Batch 27/160 → Batch Loss: 0.0248
#   Epoch 5, Batch 28/160 → Batch Loss: 0.1798
#   Epoch 5, Batch 29/160 → Batch Loss: 0.0851
#   Epoch 5, Batch 30/160 → Batch Loss: 0.0794
#   Epoch 5, Batch 31/160 → Batch Loss: 0.2707
#   Epoch 5, Batch 32/160 → Batch Loss: 0.0326
#   Epoch 5, Batch 33/160 → Batch Loss: 0.0991
#   Epoch 5, Batch 34/160 → Batch Loss: 0.0116
#   Epoch 5, Batch 35/160 → Batch Loss: 0.0300
#   Epoch 5, Batch 36/160 → Batch Loss: 0.0071
#   Epoch 5, Batch 37/160 → Batch Loss: 0.1621
#   Epoch 5, Batch 38/160 → Batch Loss: 0.0076
#   Epoch 5, Batch 39/160 → Batch Loss: 0.0751
#   Epoch 5, Batch 40/160 → Batch Loss: 0.0938
#   Epoch 5, Batch 41/160 → Batch Loss: 0.1203
#   Epoch 5, Batch 42/160 → Batch Loss: 0.2143
#   Epoch 5, Batch 43/160 → Batch Loss: 0.1220
#   Epoch 5, Batch 44/160 → Batch Loss: -0.0165
#   Epoch 5, Batch 45/160 → Batch Loss: -0.0081
#   Epoch 5, Batch 46/160 → Batch Loss: 0.0419
#   Epoch 5, Batch 47/160 → Batch Loss: 0.0117
#   Epoch 5, Batch 48/160 → Batch Loss: 0.0865
#   Epoch 5, Batch 49/160 → Batch Loss: 3.2317
#   Epoch 5, Batch 50/160 → Batch Loss: 0.0822
#   Epoch 5, Batch 51/160 → Batch Loss: 0.0140
#   Epoch 5, Batch 52/160 → Batch Loss: 0.1033
#   Epoch 5, Batch 53/160 → Batch Loss: -0.0053
#   Epoch 5, Batch 54/160 → Batch Loss: 0.0165
#   Epoch 5, Batch 55/160 → Batch Loss: -0.0396
#   Epoch 5, Batch 56/160 → Batch Loss: 0.0861
#   Epoch 5, Batch 57/160 → Batch Loss: -0.0176
#   Epoch 5, Batch 58/160 → Batch Loss: 13.6070
#   Epoch 5, Batch 59/160 → Batch Loss: 0.1167
#   Epoch 5, Batch 60/160 → Batch Loss: 0.0641
#   Epoch 5, Batch 61/160 → Batch Loss: 0.0328
#   Epoch 5, Batch 62/160 → Batch Loss: 0.0680
#   Epoch 5, Batch 63/160 → Batch Loss: 0.0337
#   Epoch 5, Batch 64/160 → Batch Loss: 0.0944
#   Epoch 5, Batch 65/160 → Batch Loss: 0.4427
#   Epoch 5, Batch 66/160 → Batch Loss: 0.0662
#   Epoch 5, Batch 67/160 → Batch Loss: 0.5366
#   Epoch 5, Batch 68/160 → Batch Loss: -0.0227
#   Epoch 5, Batch 69/160 → Batch Loss: 0.0207
#   Epoch 5, Batch 70/160 → Batch Loss: 0.1490
#   Epoch 5, Batch 71/160 → Batch Loss: -0.0352
#   Epoch 5, Batch 72/160 → Batch Loss: -0.0532
#   Epoch 5, Batch 73/160 → Batch Loss: 0.0245
#   Epoch 5, Batch 74/160 → Batch Loss: 0.0660
#   Epoch 5, Batch 75/160 → Batch Loss: 0.1025
#   Epoch 5, Batch 76/160 → Batch Loss: -0.0215
#   Epoch 5, Batch 77/160 → Batch Loss: -0.0139
#   Epoch 5, Batch 78/160 → Batch Loss: 0.0860
#   Epoch 5, Batch 79/160 → Batch Loss: 0.1025
#   Epoch 5, Batch 80/160 → Batch Loss: 0.1400
#   Epoch 5, Batch 81/160 → Batch Loss: -0.0064
#   Epoch 5, Batch 82/160 → Batch Loss: -0.0229
#   Epoch 5, Batch 83/160 → Batch Loss: 0.0022
#   Epoch 5, Batch 84/160 → Batch Loss: 0.1129
#   Epoch 5, Batch 85/160 → Batch Loss: 0.0169
#   Epoch 5, Batch 86/160 → Batch Loss: 0.3301
#   Epoch 5, Batch 87/160 → Batch Loss: 0.0070
#   Epoch 5, Batch 88/160 → Batch Loss: 0.0401
#   Epoch 5, Batch 89/160 → Batch Loss: 0.2197
#   Epoch 5, Batch 90/160 → Batch Loss: 0.0796
#   Epoch 5, Batch 91/160 → Batch Loss: 0.0816
#   Epoch 5, Batch 92/160 → Batch Loss: 0.1097
#   Epoch 5, Batch 93/160 → Batch Loss: 0.0385
#   Epoch 5, Batch 94/160 → Batch Loss: 0.0050
#   Epoch 5, Batch 95/160 → Batch Loss: 0.2488
#   Epoch 5, Batch 96/160 → Batch Loss: -0.0415
#   Epoch 5, Batch 97/160 → Batch Loss: 0.1002
#   Epoch 5, Batch 98/160 → Batch Loss: 0.2403
#   Epoch 5, Batch 99/160 → Batch Loss: 0.1205
#   Epoch 5, Batch 100/160 → Batch Loss: 0.8093
#   Epoch 5, Batch 101/160 → Batch Loss: 0.0220
#   Epoch 5, Batch 102/160 → Batch Loss: 0.0571
#   Epoch 5, Batch 103/160 → Batch Loss: 0.0612
#   Epoch 5, Batch 104/160 → Batch Loss: 0.0275
#   Epoch 5, Batch 105/160 → Batch Loss: 0.1473
#   Epoch 5, Batch 106/160 → Batch Loss: 0.0938
#   Epoch 5, Batch 107/160 → Batch Loss: 0.0946
#   Epoch 5, Batch 108/160 → Batch Loss: -0.0149
#   Epoch 5, Batch 109/160 → Batch Loss: 0.7513
#   Epoch 5, Batch 110/160 → Batch Loss: 0.0508
#   Epoch 5, Batch 111/160 → Batch Loss: 0.3281
#   Epoch 5, Batch 112/160 → Batch Loss: 0.0930
#   Epoch 5, Batch 113/160 → Batch Loss: 0.0287
#   Epoch 5, Batch 114/160 → Batch Loss: -0.0378
#   Epoch 5, Batch 115/160 → Batch Loss: 0.0349
#   Epoch 5, Batch 116/160 → Batch Loss: 0.0820
#   Epoch 5, Batch 117/160 → Batch Loss: 0.1361
#   Epoch 5, Batch 118/160 → Batch Loss: 0.2290
#   Epoch 5, Batch 119/160 → Batch Loss: 0.0986
#   Epoch 5, Batch 120/160 → Batch Loss: -0.0141
#   Epoch 5, Batch 121/160 → Batch Loss: -0.0127
#   Epoch 5, Batch 122/160 → Batch Loss: 0.1866
#   Epoch 5, Batch 123/160 → Batch Loss: 0.5915
#   Epoch 5, Batch 124/160 → Batch Loss: 0.0184
#   Epoch 5, Batch 125/160 → Batch Loss: 0.0406
#   Epoch 5, Batch 126/160 → Batch Loss: 0.0577
#   Epoch 5, Batch 127/160 → Batch Loss: 0.1376
#   Epoch 5, Batch 128/160 → Batch Loss: -0.0080
#   Epoch 5, Batch 129/160 → Batch Loss: -0.0052
#   Epoch 5, Batch 130/160 → Batch Loss: 0.0160
#   Epoch 5, Batch 131/160 → Batch Loss: 0.0311
#   Epoch 5, Batch 132/160 → Batch Loss: 0.0005
#   Epoch 5, Batch 133/160 → Batch Loss: 0.1051
#   Epoch 5, Batch 134/160 → Batch Loss: 0.0542
#   Epoch 5, Batch 135/160 → Batch Loss: 0.1138
#   Epoch 5, Batch 136/160 → Batch Loss: 0.0453
#   Epoch 5, Batch 137/160 → Batch Loss: 0.1180
#   Epoch 5, Batch 138/160 → Batch Loss: 0.0814
#   Epoch 5, Batch 139/160 → Batch Loss: -0.0311
#   Epoch 5, Batch 140/160 → Batch Loss: 0.1349
#   Epoch 5, Batch 141/160 → Batch Loss: -0.0372
#   Epoch 5, Batch 142/160 → Batch Loss: 0.0940
#   Epoch 5, Batch 143/160 → Batch Loss: 0.0401
#   Epoch 5, Batch 144/160 → Batch Loss: 0.0817
#   Epoch 5, Batch 145/160 → Batch Loss: -0.0110
#   Epoch 5, Batch 146/160 → Batch Loss: -0.0447
#   Epoch 5, Batch 147/160 → Batch Loss: 0.4553
#   Epoch 5, Batch 148/160 → Batch Loss: 0.0650
#   Epoch 5, Batch 149/160 → Batch Loss: -0.0717
#   Epoch 5, Batch 150/160 → Batch Loss: 0.0331
#   Epoch 5, Batch 151/160 → Batch Loss: 0.1292
#   Epoch 5, Batch 152/160 → Batch Loss: 0.1015
#   Epoch 5, Batch 153/160 → Batch Loss: -0.0046
#   Epoch 5, Batch 154/160 → Batch Loss: -0.0303
#   Epoch 5, Batch 155/160 → Batch Loss: 0.0453
#   Epoch 5, Batch 156/160 → Batch Loss: 0.0890
#   Epoch 5, Batch 157/160 → Batch Loss: 0.0575
#   Epoch 5, Batch 158/160 → Batch Loss: 0.0423
#   Epoch 5, Batch 159/160 → Batch Loss: 0.0182
#   Epoch 5, Batch 160/160 → Batch Loss: 0.0468
#   Epoch 6, Batch 1/160 → Batch Loss: -0.0535
#   Epoch 6, Batch 2/160 → Batch Loss: -0.0410
#   Epoch 6, Batch 3/160 → Batch Loss: 0.0689
#   Epoch 6, Batch 4/160 → Batch Loss: 0.0287
#   Epoch 6, Batch 5/160 → Batch Loss: 0.2335
#   Epoch 6, Batch 6/160 → Batch Loss: 0.1052
#   Epoch 6, Batch 7/160 → Batch Loss: -0.0354
#   Epoch 6, Batch 8/160 → Batch Loss: 0.2709
#   Epoch 6, Batch 9/160 → Batch Loss: 0.0156
#   Epoch 6, Batch 10/160 → Batch Loss: 0.0505
#   Epoch 6, Batch 11/160 → Batch Loss: -0.0585
#   Epoch 6, Batch 12/160 → Batch Loss: 0.0398
#   Epoch 6, Batch 13/160 → Batch Loss: 0.1194
#   Epoch 6, Batch 14/160 → Batch Loss: 0.0156
#   Epoch 6, Batch 15/160 → Batch Loss: 0.0497
#   Epoch 6, Batch 16/160 → Batch Loss: 0.1014
#   Epoch 6, Batch 17/160 → Batch Loss: 0.0882
#   Epoch 6, Batch 18/160 → Batch Loss: 0.0396
#   Epoch 6, Batch 19/160 → Batch Loss: 0.1085
#   Epoch 6, Batch 20/160 → Batch Loss: 0.0355
#   Epoch 6, Batch 21/160 → Batch Loss: 0.0003
#   Epoch 6, Batch 22/160 → Batch Loss: 0.0558
#   Epoch 6, Batch 23/160 → Batch Loss: 0.0336
#   Epoch 6, Batch 24/160 → Batch Loss: 0.1211
#   Epoch 6, Batch 25/160 → Batch Loss: 0.0692
#   Epoch 6, Batch 26/160 → Batch Loss: 0.0282
#   Epoch 6, Batch 27/160 → Batch Loss: 0.1973
#   Epoch 6, Batch 28/160 → Batch Loss: 0.0588
#   Epoch 6, Batch 29/160 → Batch Loss: 0.0297
#   Epoch 6, Batch 30/160 → Batch Loss: 0.0186
#   Epoch 6, Batch 31/160 → Batch Loss: 0.1211
#   Epoch 6, Batch 32/160 → Batch Loss: 0.0651
#   Epoch 6, Batch 33/160 → Batch Loss: 0.1743
#   Epoch 6, Batch 34/160 → Batch Loss: 0.0333
#   Epoch 6, Batch 35/160 → Batch Loss: 0.0368
#   Epoch 6, Batch 36/160 → Batch Loss: 0.0569
#   Epoch 6, Batch 37/160 → Batch Loss: 0.1068
#   Epoch 6, Batch 38/160 → Batch Loss: 0.0442
#   Epoch 6, Batch 39/160 → Batch Loss: 0.1367
#   Epoch 6, Batch 40/160 → Batch Loss: 0.1083
#   Epoch 6, Batch 41/160 → Batch Loss: 0.0562
#   Epoch 6, Batch 42/160 → Batch Loss: 0.0155
#   Epoch 6, Batch 43/160 → Batch Loss: 0.0525
#   Epoch 6, Batch 44/160 → Batch Loss: 0.0874
#   Epoch 6, Batch 45/160 → Batch Loss: 0.0498
#   Epoch 6, Batch 46/160 → Batch Loss: -0.0184
#   Epoch 6, Batch 47/160 → Batch Loss: 0.2749
#   Epoch 6, Batch 48/160 → Batch Loss: 0.0647
#   Epoch 6, Batch 49/160 → Batch Loss: 0.0511
#   Epoch 6, Batch 50/160 → Batch Loss: -0.0327
#   Epoch 6, Batch 51/160 → Batch Loss: 0.0187
#   Epoch 6, Batch 52/160 → Batch Loss: 0.0219
#   Epoch 6, Batch 53/160 → Batch Loss: 0.4559
#   Epoch 6, Batch 54/160 → Batch Loss: 0.0458
#   Epoch 6, Batch 55/160 → Batch Loss: 0.0755
#   Epoch 6, Batch 56/160 → Batch Loss: -0.0176
#   Epoch 6, Batch 57/160 → Batch Loss: 0.4341
#   Epoch 6, Batch 58/160 → Batch Loss: 0.0203
#   Epoch 6, Batch 59/160 → Batch Loss: 0.1323
#   Epoch 6, Batch 60/160 → Batch Loss: 0.0559
#   Epoch 6, Batch 61/160 → Batch Loss: 0.0345
#   Epoch 6, Batch 62/160 → Batch Loss: 0.0686
#   Epoch 6, Batch 63/160 → Batch Loss: 0.6894
#   Epoch 6, Batch 64/160 → Batch Loss: 0.0029
#   Epoch 6, Batch 65/160 → Batch Loss: -0.0138
#   Epoch 6, Batch 66/160 → Batch Loss: 0.0631
#   Epoch 6, Batch 67/160 → Batch Loss: 0.0188
#   Epoch 6, Batch 68/160 → Batch Loss: 0.6971
#   Epoch 6, Batch 69/160 → Batch Loss: 0.1003
#   Epoch 6, Batch 70/160 → Batch Loss: -0.0215
#   Epoch 6, Batch 71/160 → Batch Loss: 13.2459
#   Epoch 6, Batch 72/160 → Batch Loss: 0.0530
#   Epoch 6, Batch 73/160 → Batch Loss: 0.0496
#   Epoch 6, Batch 74/160 → Batch Loss: 0.1628
#   Epoch 6, Batch 75/160 → Batch Loss: 0.0345
#   Epoch 6, Batch 76/160 → Batch Loss: 0.2531
#   Epoch 6, Batch 77/160 → Batch Loss: 0.1490
#   Epoch 6, Batch 78/160 → Batch Loss: 0.0152
#   Epoch 6, Batch 79/160 → Batch Loss: 0.6152
#   Epoch 6, Batch 80/160 → Batch Loss: 0.0499
#   Epoch 6, Batch 81/160 → Batch Loss: 0.1704
#   Epoch 6, Batch 82/160 → Batch Loss: 0.0631
#   Epoch 6, Batch 83/160 → Batch Loss: -0.0382
#   Epoch 6, Batch 84/160 → Batch Loss: 0.1949
#   Epoch 6, Batch 85/160 → Batch Loss: 0.0276
#   Epoch 6, Batch 86/160 → Batch Loss: 0.0820
#   Epoch 6, Batch 87/160 → Batch Loss: 0.0535
#   Epoch 6, Batch 88/160 → Batch Loss: 0.0821
#   Epoch 6, Batch 89/160 → Batch Loss: -0.0025
#   Epoch 6, Batch 90/160 → Batch Loss: 0.1031
#   Epoch 6, Batch 91/160 → Batch Loss: 0.0214
#   Epoch 6, Batch 92/160 → Batch Loss: 0.0041
#   Epoch 6, Batch 93/160 → Batch Loss: 0.0197
#   Epoch 6, Batch 94/160 → Batch Loss: 0.0402
#   Epoch 6, Batch 95/160 → Batch Loss: 0.0127
#   Epoch 6, Batch 96/160 → Batch Loss: 0.0072
#   Epoch 6, Batch 97/160 → Batch Loss: 0.0146
#   Epoch 6, Batch 98/160 → Batch Loss: -0.0243
#   Epoch 6, Batch 99/160 → Batch Loss: -0.0150
#   Epoch 6, Batch 100/160 → Batch Loss: 0.0277
#   Epoch 6, Batch 101/160 → Batch Loss: 0.1163
#   Epoch 6, Batch 102/160 → Batch Loss: -0.0634
#   Epoch 6, Batch 103/160 → Batch Loss: 0.1496
#   Epoch 6, Batch 104/160 → Batch Loss: 0.1137
#   Epoch 6, Batch 105/160 → Batch Loss: 0.0567
#   Epoch 6, Batch 106/160 → Batch Loss: 0.0695
#   Epoch 6, Batch 107/160 → Batch Loss: 0.1399
#   Epoch 6, Batch 108/160 → Batch Loss: -0.0120
#   Epoch 6, Batch 109/160 → Batch Loss: 0.0555
#   Epoch 6, Batch 110/160 → Batch Loss: 0.0858
#   Epoch 6, Batch 111/160 → Batch Loss: 0.1196
#   Epoch 6, Batch 112/160 → Batch Loss: 0.0343
#   Epoch 6, Batch 113/160 → Batch Loss: -0.0063
#   Epoch 6, Batch 114/160 → Batch Loss: 0.3708
#   Epoch 6, Batch 115/160 → Batch Loss: 0.0060
#   Epoch 6, Batch 116/160 → Batch Loss: 0.0336
#   Epoch 6, Batch 117/160 → Batch Loss: 0.0432
#   Epoch 6, Batch 118/160 → Batch Loss: -0.0168
#   Epoch 6, Batch 119/160 → Batch Loss: 0.3691
#   Epoch 6, Batch 120/160 → Batch Loss: 0.0581
#   Epoch 6, Batch 121/160 → Batch Loss: 0.0015
#   Epoch 6, Batch 122/160 → Batch Loss: 0.1290
#   Epoch 6, Batch 123/160 → Batch Loss: 0.0321
#   Epoch 6, Batch 124/160 → Batch Loss: 0.0740
#   Epoch 6, Batch 125/160 → Batch Loss: 0.0376
#   Epoch 6, Batch 126/160 → Batch Loss: 0.0576
#   Epoch 6, Batch 127/160 → Batch Loss: 0.0467
#   Epoch 6, Batch 128/160 → Batch Loss: 0.0236
#   Epoch 6, Batch 129/160 → Batch Loss: 0.0510
#   Epoch 6, Batch 130/160 → Batch Loss: -0.0415
#   Epoch 6, Batch 131/160 → Batch Loss: -0.0060
#   Epoch 6, Batch 132/160 → Batch Loss: 0.0061
#   Epoch 6, Batch 133/160 → Batch Loss: 0.0017
#   Epoch 6, Batch 134/160 → Batch Loss: -0.0405
#   Epoch 6, Batch 135/160 → Batch Loss: 0.0495
#   Epoch 6, Batch 136/160 → Batch Loss: 0.0659
#   Epoch 6, Batch 137/160 → Batch Loss: 0.0977
#   Epoch 6, Batch 138/160 → Batch Loss: 0.3801
#   Epoch 6, Batch 139/160 → Batch Loss: 0.0377
#   Epoch 6, Batch 140/160 → Batch Loss: 0.1229
#   Epoch 6, Batch 141/160 → Batch Loss: 0.1644
#   Epoch 6, Batch 142/160 → Batch Loss: 0.1239
#   Epoch 6, Batch 143/160 → Batch Loss: 0.0669
#   Epoch 6, Batch 144/160 → Batch Loss: 0.1040
#   Epoch 6, Batch 145/160 → Batch Loss: 3.5292
#   Epoch 6, Batch 146/160 → Batch Loss: 0.0411
#   Epoch 6, Batch 147/160 → Batch Loss: 0.1867
#   Epoch 6, Batch 148/160 → Batch Loss: 0.2431
#   Epoch 6, Batch 149/160 → Batch Loss: 0.0186
#   Epoch 6, Batch 150/160 → Batch Loss: 0.0263
#   Epoch 6, Batch 151/160 → Batch Loss: -0.0190
#   Epoch 6, Batch 152/160 → Batch Loss: 0.0704
#   Epoch 6, Batch 153/160 → Batch Loss: 0.0597
#   Epoch 6, Batch 154/160 → Batch Loss: 0.0028
#   Epoch 6, Batch 155/160 → Batch Loss: -0.0290
#   Epoch 6, Batch 156/160 → Batch Loss: 0.0665
#   Epoch 6, Batch 157/160 → Batch Loss: 0.1508
#   Epoch 6, Batch 158/160 → Batch Loss: 0.0643
#   Epoch 6, Batch 159/160 → Batch Loss: 0.3830
#   Epoch 6, Batch 160/160 → Batch Loss: -0.0488
#   Epoch 7, Batch 1/160 → Batch Loss: 0.0395
#   Epoch 7, Batch 2/160 → Batch Loss: 0.0899
#   Epoch 7, Batch 3/160 → Batch Loss: 0.0253
#   Epoch 7, Batch 4/160 → Batch Loss: 0.0932
#   Epoch 7, Batch 5/160 → Batch Loss: 0.0146
#   Epoch 7, Batch 6/160 → Batch Loss: 0.0816
#   Epoch 7, Batch 7/160 → Batch Loss: 0.1309
#   Epoch 7, Batch 8/160 → Batch Loss: 0.0962
#   Epoch 7, Batch 9/160 → Batch Loss: 0.0387
#   Epoch 7, Batch 10/160 → Batch Loss: 0.0450
#   Epoch 7, Batch 11/160 → Batch Loss: 0.1783
#   Epoch 7, Batch 12/160 → Batch Loss: 0.0178
#   Epoch 7, Batch 13/160 → Batch Loss: 0.0457
#   Epoch 7, Batch 14/160 → Batch Loss: 0.9137
#   Epoch 7, Batch 15/160 → Batch Loss: 0.0870
#   Epoch 7, Batch 16/160 → Batch Loss: 0.0544
#   Epoch 7, Batch 17/160 → Batch Loss: -0.0258
#   Epoch 7, Batch 18/160 → Batch Loss: 0.0300
#   Epoch 7, Batch 19/160 → Batch Loss: 0.0432
#   Epoch 7, Batch 20/160 → Batch Loss: 0.0811
#   Epoch 7, Batch 21/160 → Batch Loss: -0.0113
#   Epoch 7, Batch 22/160 → Batch Loss: 0.1162
#   Epoch 7, Batch 23/160 → Batch Loss: -0.0176
#   Epoch 7, Batch 24/160 → Batch Loss: 0.0396
#   Epoch 7, Batch 25/160 → Batch Loss: -0.0355
#   Epoch 7, Batch 26/160 → Batch Loss: 0.0202
#   Epoch 7, Batch 27/160 → Batch Loss: 0.0605
#   Epoch 7, Batch 28/160 → Batch Loss: 0.1686
#   Epoch 7, Batch 29/160 → Batch Loss: 0.0236
#   Epoch 7, Batch 30/160 → Batch Loss: 0.4311
#   Epoch 7, Batch 31/160 → Batch Loss: 0.0249
#   Epoch 7, Batch 32/160 → Batch Loss: 0.0549
#   Epoch 7, Batch 33/160 → Batch Loss: 0.0916
#   Epoch 7, Batch 34/160 → Batch Loss: 0.0620
#   Epoch 7, Batch 35/160 → Batch Loss: 0.0377
#   Epoch 7, Batch 36/160 → Batch Loss: 0.1112
#   Epoch 7, Batch 37/160 → Batch Loss: 0.1937
#   Epoch 7, Batch 38/160 → Batch Loss: -0.0183
#   Epoch 7, Batch 39/160 → Batch Loss: 0.0252
#   Epoch 7, Batch 40/160 → Batch Loss: 0.0778
#   Epoch 7, Batch 41/160 → Batch Loss: 0.0496
#   Epoch 7, Batch 42/160 → Batch Loss: 0.0136
#   Epoch 7, Batch 43/160 → Batch Loss: 0.0233
#   Epoch 7, Batch 44/160 → Batch Loss: -0.0026
#   Epoch 7, Batch 45/160 → Batch Loss: 0.0205
#   Epoch 7, Batch 46/160 → Batch Loss: 0.0313
#   Epoch 7, Batch 47/160 → Batch Loss: 0.1247
#   Epoch 7, Batch 48/160 → Batch Loss: -0.0101
#   Epoch 7, Batch 49/160 → Batch Loss: 0.1088
#   Epoch 7, Batch 50/160 → Batch Loss: 0.2896
#   Epoch 7, Batch 51/160 → Batch Loss: 0.0369
#   Epoch 7, Batch 52/160 → Batch Loss: 0.0275
#   Epoch 7, Batch 53/160 → Batch Loss: -0.0079
#   Epoch 7, Batch 54/160 → Batch Loss: 0.0774
#   Epoch 7, Batch 55/160 → Batch Loss: 0.0287
#   Epoch 7, Batch 56/160 → Batch Loss: -0.0081
#   Epoch 7, Batch 57/160 → Batch Loss: -0.0026
#   Epoch 7, Batch 58/160 → Batch Loss: 0.0207
#   Epoch 7, Batch 59/160 → Batch Loss: 0.2904
#   Epoch 7, Batch 60/160 → Batch Loss: -0.0023
#   Epoch 7, Batch 61/160 → Batch Loss: 0.3846
#   Epoch 7, Batch 62/160 → Batch Loss: -0.0115
#   Epoch 7, Batch 63/160 → Batch Loss: -0.0056
#   Epoch 7, Batch 64/160 → Batch Loss: 0.0772
#   Epoch 7, Batch 65/160 → Batch Loss: 0.1303
#   Epoch 7, Batch 66/160 → Batch Loss: 0.2418
#   Epoch 7, Batch 67/160 → Batch Loss: 0.2794
#   Epoch 7, Batch 68/160 → Batch Loss: 0.0138
#   Epoch 7, Batch 69/160 → Batch Loss: 0.9338
#   Epoch 7, Batch 70/160 → Batch Loss: 0.0201
#   Epoch 7, Batch 71/160 → Batch Loss: -0.0178
#   Epoch 7, Batch 72/160 → Batch Loss: 0.1315
#   Epoch 7, Batch 73/160 → Batch Loss: 0.0629
#   Epoch 7, Batch 74/160 → Batch Loss: 0.1567
#   Epoch 7, Batch 75/160 → Batch Loss: 0.0081
#   Epoch 7, Batch 76/160 → Batch Loss: 0.0661
#   Epoch 7, Batch 77/160 → Batch Loss: 0.0352
#   Epoch 7, Batch 78/160 → Batch Loss: 0.1192
#   Epoch 7, Batch 79/160 → Batch Loss: 13.5966
#   Epoch 7, Batch 80/160 → Batch Loss: -0.0244
#   Epoch 7, Batch 81/160 → Batch Loss: 0.0273
#   Epoch 7, Batch 82/160 → Batch Loss: 0.1985
#   Epoch 7, Batch 83/160 → Batch Loss: 0.0005
#   Epoch 7, Batch 84/160 → Batch Loss: 0.1263
#   Epoch 7, Batch 85/160 → Batch Loss: 0.0587
#   Epoch 7, Batch 86/160 → Batch Loss: 0.0152
#   Epoch 7, Batch 87/160 → Batch Loss: 0.1189
#   Epoch 7, Batch 88/160 → Batch Loss: 0.0118
#   Epoch 7, Batch 89/160 → Batch Loss: 0.0039
#   Epoch 7, Batch 90/160 → Batch Loss: 0.0337
#   Epoch 7, Batch 91/160 → Batch Loss: 0.0435
#   Epoch 7, Batch 92/160 → Batch Loss: 0.2220
#   Epoch 7, Batch 93/160 → Batch Loss: -0.0048
#   Epoch 7, Batch 94/160 → Batch Loss: 0.0676
#   Epoch 7, Batch 95/160 → Batch Loss: 0.0360
# ...
#   Epoch 298, Batch 145/160 → Batch Loss: 0.0381
#   Epoch 298, Batch 146/160 → Batch Loss: -0.0074
#   Epoch 298, Batch 147/160 → Batch Loss: 0.0467
#   Epoch 298, Batch 148/160 → Batch Loss: 0.0267
#   Epoch 298, Batch 149/160 → Batch Loss: 0.0362
#   Epoch 298, Batch 150/160 → Batch Loss: 0.0622
#   Epoch 298, Batch 151/160 → Batch Loss: 0.0605
#   Epoch 298, Batch 152/160 → Batch Loss: 0.0844
#   Epoch 298, Batch 153/160 → Batch Loss: 0.0043
#   Epoch 298, Batch 154/160 → Batch Loss: 0.0235
#   Epoch 298, Batch 155/160 → Batch Loss: -0.0515
#   Epoch 298, Batch 156/160 → Batch Loss: 0.0311
#   Epoch 298, Batch 157/160 → Batch Loss: 0.0391
#   Epoch 298, Batch 158/160 → Batch Loss: 0.0460
#   Epoch 298, Batch 159/160 → Batch Loss: 0.0034
#   Epoch 298, Batch 160/160 → Batch Loss: 0.0176
#   Epoch 299, Batch 1/160 → Batch Loss: 0.0263
#   Epoch 299, Batch 2/160 → Batch Loss: 0.0237
#   Epoch 299, Batch 3/160 → Batch Loss: 0.1038
#   Epoch 299, Batch 4/160 → Batch Loss: 0.0304
#   Epoch 299, Batch 5/160 → Batch Loss: 0.0365
#   Epoch 299, Batch 6/160 → Batch Loss: 0.0043
#   Epoch 299, Batch 7/160 → Batch Loss: -0.0133
#   Epoch 299, Batch 8/160 → Batch Loss: -0.0043
#   Epoch 299, Batch 9/160 → Batch Loss: 0.0709
#   Epoch 299, Batch 10/160 → Batch Loss: -0.0009
#   Epoch 299, Batch 11/160 → Batch Loss: 0.0231
#   Epoch 299, Batch 12/160 → Batch Loss: 0.0571
#   Epoch 299, Batch 13/160 → Batch Loss: 0.0474
#   Epoch 299, Batch 14/160 → Batch Loss: 0.0578
#   Epoch 299, Batch 15/160 → Batch Loss: 0.0683
#   Epoch 299, Batch 16/160 → Batch Loss: -0.0059
#   Epoch 299, Batch 17/160 → Batch Loss: 0.0297
#   Epoch 299, Batch 18/160 → Batch Loss: 0.0722
#   Epoch 299, Batch 19/160 → Batch Loss: 0.0345
#   Epoch 299, Batch 20/160 → Batch Loss: 0.0204
#   Epoch 299, Batch 21/160 → Batch Loss: 0.0571
#   Epoch 299, Batch 22/160 → Batch Loss: 0.0270
#   Epoch 299, Batch 23/160 → Batch Loss: 0.0312
#   Epoch 299, Batch 24/160 → Batch Loss: 0.0013
#   Epoch 299, Batch 25/160 → Batch Loss: 0.0921
#   Epoch 299, Batch 26/160 → Batch Loss: 0.0142
#   Epoch 299, Batch 27/160 → Batch Loss: -0.0230
#   Epoch 299, Batch 28/160 → Batch Loss: 0.0993
#   Epoch 299, Batch 29/160 → Batch Loss: 0.0083
#   Epoch 299, Batch 30/160 → Batch Loss: 0.0010
#   Epoch 299, Batch 31/160 → Batch Loss: 0.0219
#   Epoch 299, Batch 32/160 → Batch Loss: 0.0355
#   Epoch 299, Batch 33/160 → Batch Loss: -0.0186
#   Epoch 299, Batch 34/160 → Batch Loss: -0.0162
#   Epoch 299, Batch 35/160 → Batch Loss: 0.0002
#   Epoch 299, Batch 36/160 → Batch Loss: 0.0071
#   Epoch 299, Batch 37/160 → Batch Loss: -0.0006
#   Epoch 299, Batch 38/160 → Batch Loss: 0.1182
#   Epoch 299, Batch 39/160 → Batch Loss: 0.1417
#   Epoch 299, Batch 40/160 → Batch Loss: 0.0066
#   Epoch 299, Batch 41/160 → Batch Loss: 0.0199
#   Epoch 299, Batch 42/160 → Batch Loss: 0.0293
#   Epoch 299, Batch 43/160 → Batch Loss: 0.0398
#   Epoch 299, Batch 44/160 → Batch Loss: 0.0169
#   Epoch 299, Batch 45/160 → Batch Loss: 0.0765
#   Epoch 299, Batch 46/160 → Batch Loss: 0.1278
#   Epoch 299, Batch 47/160 → Batch Loss: 0.0013
#   Epoch 299, Batch 48/160 → Batch Loss: 0.0228
#   Epoch 299, Batch 49/160 → Batch Loss: 0.0262
#   Epoch 299, Batch 50/160 → Batch Loss: -0.0034
#   Epoch 299, Batch 51/160 → Batch Loss: 0.0969
#   Epoch 299, Batch 52/160 → Batch Loss: 0.2987
#   Epoch 299, Batch 53/160 → Batch Loss: 0.0363
#   Epoch 299, Batch 54/160 → Batch Loss: 0.0305
#   Epoch 299, Batch 55/160 → Batch Loss: -0.0172
#   Epoch 299, Batch 56/160 → Batch Loss: 0.1027
#   Epoch 299, Batch 57/160 → Batch Loss: 0.0655
#   Epoch 299, Batch 58/160 → Batch Loss: 0.0143
#   Epoch 299, Batch 59/160 → Batch Loss: 0.0489
#   Epoch 299, Batch 60/160 → Batch Loss: -0.0014
#   Epoch 299, Batch 61/160 → Batch Loss: 0.0415
#   Epoch 299, Batch 62/160 → Batch Loss: -0.0244
#   Epoch 299, Batch 63/160 → Batch Loss: 0.0335
#   Epoch 299, Batch 64/160 → Batch Loss: -0.0402
#   Epoch 299, Batch 65/160 → Batch Loss: 0.0298
#   Epoch 299, Batch 66/160 → Batch Loss: 0.0520
#   Epoch 299, Batch 67/160 → Batch Loss: -0.0292
#   Epoch 299, Batch 68/160 → Batch Loss: -0.0208
#   Epoch 299, Batch 69/160 → Batch Loss: -0.0247
#   Epoch 299, Batch 70/160 → Batch Loss: 0.1080
#   Epoch 299, Batch 71/160 → Batch Loss: -0.0514
#   Epoch 299, Batch 72/160 → Batch Loss: -0.0079
#   Epoch 299, Batch 73/160 → Batch Loss: 0.0458
#   Epoch 299, Batch 74/160 → Batch Loss: 0.0550
#   Epoch 299, Batch 75/160 → Batch Loss: 0.0255
#   Epoch 299, Batch 76/160 → Batch Loss: 0.0820
#   Epoch 299, Batch 77/160 → Batch Loss: 0.0240
#   Epoch 299, Batch 78/160 → Batch Loss: 0.0476
#   Epoch 299, Batch 79/160 → Batch Loss: 0.0065
#   Epoch 299, Batch 80/160 → Batch Loss: 0.0958
#   Epoch 299, Batch 81/160 → Batch Loss: 0.0603
#   Epoch 299, Batch 82/160 → Batch Loss: -0.0102
#   Epoch 299, Batch 83/160 → Batch Loss: 0.0331
#   Epoch 299, Batch 84/160 → Batch Loss: -0.0111
#   Epoch 299, Batch 85/160 → Batch Loss: 0.0049
#   Epoch 299, Batch 86/160 → Batch Loss: 0.0483
#   Epoch 299, Batch 87/160 → Batch Loss: -0.0165
#   Epoch 299, Batch 88/160 → Batch Loss: 0.0317
#   Epoch 299, Batch 89/160 → Batch Loss: 0.0213
#   Epoch 299, Batch 90/160 → Batch Loss: 0.0032
#   Epoch 299, Batch 91/160 → Batch Loss: 0.0451
#   Epoch 299, Batch 92/160 → Batch Loss: 0.0755
#   Epoch 299, Batch 93/160 → Batch Loss: 0.0771
#   Epoch 299, Batch 94/160 → Batch Loss: 0.0152
#   Epoch 299, Batch 95/160 → Batch Loss: 0.0369
#   Epoch 299, Batch 96/160 → Batch Loss: 0.0530
#   Epoch 299, Batch 97/160 → Batch Loss: 0.0292
#   Epoch 299, Batch 98/160 → Batch Loss: 0.0339
#   Epoch 299, Batch 99/160 → Batch Loss: 0.0138
#   Epoch 299, Batch 100/160 → Batch Loss: 0.0146
#   Epoch 299, Batch 101/160 → Batch Loss: 0.0930
#   Epoch 299, Batch 102/160 → Batch Loss: 0.0327
#   Epoch 299, Batch 103/160 → Batch Loss: 0.0256
#   Epoch 299, Batch 104/160 → Batch Loss: 0.0068
#   Epoch 299, Batch 105/160 → Batch Loss: 0.0289
#   Epoch 299, Batch 106/160 → Batch Loss: 0.0168
#   Epoch 299, Batch 107/160 → Batch Loss: 0.0857
#   Epoch 299, Batch 108/160 → Batch Loss: 0.0120
#   Epoch 299, Batch 109/160 → Batch Loss: 0.0222
#   Epoch 299, Batch 110/160 → Batch Loss: -0.0086
#   Epoch 299, Batch 111/160 → Batch Loss: 0.0604
#   Epoch 299, Batch 112/160 → Batch Loss: 0.0244
#   Epoch 299, Batch 113/160 → Batch Loss: 0.0512
#   Epoch 299, Batch 114/160 → Batch Loss: -0.0142
#   Epoch 299, Batch 115/160 → Batch Loss: -0.0087
#   Epoch 299, Batch 116/160 → Batch Loss: 0.0271
#   Epoch 299, Batch 117/160 → Batch Loss: 0.0800
#   Epoch 299, Batch 118/160 → Batch Loss: 0.0062
#   Epoch 299, Batch 119/160 → Batch Loss: -0.0202
#   Epoch 299, Batch 120/160 → Batch Loss: 0.0115
#   Epoch 299, Batch 121/160 → Batch Loss: 0.0642
#   Epoch 299, Batch 122/160 → Batch Loss: 0.0385
#   Epoch 299, Batch 123/160 → Batch Loss: 0.0348
#   Epoch 299, Batch 124/160 → Batch Loss: 0.0527
#   Epoch 299, Batch 125/160 → Batch Loss: 0.0116
#   Epoch 299, Batch 126/160 → Batch Loss: -0.0334
#   Epoch 299, Batch 127/160 → Batch Loss: 0.0405
#   Epoch 299, Batch 128/160 → Batch Loss: 0.2754
#   Epoch 299, Batch 129/160 → Batch Loss: 0.0163
#   Epoch 299, Batch 130/160 → Batch Loss: 0.0301
#   Epoch 299, Batch 131/160 → Batch Loss: 0.0609
#   Epoch 299, Batch 132/160 → Batch Loss: 0.0138
#   Epoch 299, Batch 133/160 → Batch Loss: -0.0137
#   Epoch 299, Batch 134/160 → Batch Loss: -0.0149
#   Epoch 299, Batch 135/160 → Batch Loss: 0.0078
#   Epoch 299, Batch 136/160 → Batch Loss: -0.0076
#   Epoch 299, Batch 137/160 → Batch Loss: 0.0510
#   Epoch 299, Batch 138/160 → Batch Loss: 0.0247
#   Epoch 299, Batch 139/160 → Batch Loss: 0.0418
#   Epoch 299, Batch 140/160 → Batch Loss: 0.0527
#   Epoch 299, Batch 141/160 → Batch Loss: 0.0707
#   Epoch 299, Batch 142/160 → Batch Loss: 0.0161
#   Epoch 299, Batch 143/160 → Batch Loss: 0.0243
#   Epoch 299, Batch 144/160 → Batch Loss: -0.0388
#   Epoch 299, Batch 145/160 → Batch Loss: 0.0074
#   Epoch 299, Batch 146/160 → Batch Loss: 0.0347
#   Epoch 299, Batch 147/160 → Batch Loss: 0.0069
#   Epoch 299, Batch 148/160 → Batch Loss: 0.0420
#   Epoch 299, Batch 149/160 → Batch Loss: 0.1298
#   Epoch 299, Batch 150/160 → Batch Loss: 0.0772
#   Epoch 299, Batch 151/160 → Batch Loss: 0.0419
#   Epoch 299, Batch 152/160 → Batch Loss: 0.0448
#   Epoch 299, Batch 153/160 → Batch Loss: 0.0256
#   Epoch 299, Batch 154/160 → Batch Loss: -0.0038
#   Epoch 299, Batch 155/160 → Batch Loss: 0.0578
#   Epoch 299, Batch 156/160 → Batch Loss: 0.0651
#   Epoch 299, Batch 157/160 → Batch Loss: 0.0627
#   Epoch 299, Batch 158/160 → Batch Loss: 0.0668
#   Epoch 299, Batch 159/160 → Batch Loss: 0.0493
#   Epoch 299, Batch 160/160 → Batch Loss: -0.0171
#   Epoch 300, Batch 1/160 → Batch Loss: -0.0013
#   Epoch 300, Batch 2/160 → Batch Loss: 0.0186
#   Epoch 300, Batch 3/160 → Batch Loss: 0.0062
#   Epoch 300, Batch 4/160 → Batch Loss: 0.0609
#   Epoch 300, Batch 5/160 → Batch Loss: 0.0501
#   Epoch 300, Batch 6/160 → Batch Loss: -0.0103
#   Epoch 300, Batch 7/160 → Batch Loss: 0.0423
#   Epoch 300, Batch 8/160 → Batch Loss: 0.0269
#   Epoch 300, Batch 9/160 → Batch Loss: 0.0411
#   Epoch 300, Batch 10/160 → Batch Loss: -0.0216
#   Epoch 300, Batch 11/160 → Batch Loss: 0.0594
#   Epoch 300, Batch 12/160 → Batch Loss: -0.0052
#   Epoch 300, Batch 13/160 → Batch Loss: 0.0098
#   Epoch 300, Batch 14/160 → Batch Loss: 0.1025
#   Epoch 300, Batch 15/160 → Batch Loss: 0.0062
#   Epoch 300, Batch 16/160 → Batch Loss: 0.0242
#   Epoch 300, Batch 17/160 → Batch Loss: 0.0112
#   Epoch 300, Batch 18/160 → Batch Loss: 0.0291
#   Epoch 300, Batch 19/160 → Batch Loss: 0.0790
#   Epoch 300, Batch 20/160 → Batch Loss: -0.0082
#   Epoch 300, Batch 21/160 → Batch Loss: 0.0410
#   Epoch 300, Batch 22/160 → Batch Loss: 0.0427
#   Epoch 300, Batch 23/160 → Batch Loss: 0.0907
#   Epoch 300, Batch 24/160 → Batch Loss: 0.0747
#   Epoch 300, Batch 25/160 → Batch Loss: 0.0618
#   Epoch 300, Batch 26/160 → Batch Loss: 0.0481
#   Epoch 300, Batch 27/160 → Batch Loss: 0.0298
#   Epoch 300, Batch 28/160 → Batch Loss: 0.0312
#   Epoch 300, Batch 29/160 → Batch Loss: 0.0268
#   Epoch 300, Batch 30/160 → Batch Loss: 0.0554
#   Epoch 300, Batch 31/160 → Batch Loss: 0.0271
#   Epoch 300, Batch 32/160 → Batch Loss: 0.0278
#   Epoch 300, Batch 33/160 → Batch Loss: -0.0166
#   Epoch 300, Batch 34/160 → Batch Loss: 0.0120
#   Epoch 300, Batch 35/160 → Batch Loss: 0.0160
#   Epoch 300, Batch 36/160 → Batch Loss: 0.0309
#   Epoch 300, Batch 37/160 → Batch Loss: -0.0047
#   Epoch 300, Batch 38/160 → Batch Loss: 0.0227
#   Epoch 300, Batch 39/160 → Batch Loss: 0.0805
#   Epoch 300, Batch 40/160 → Batch Loss: 0.0074
#   Epoch 300, Batch 41/160 → Batch Loss: 0.0610
#   Epoch 300, Batch 42/160 → Batch Loss: 0.0564
#   Epoch 300, Batch 43/160 → Batch Loss: -0.0145
#   Epoch 300, Batch 44/160 → Batch Loss: 0.0530
#   Epoch 300, Batch 45/160 → Batch Loss: 0.1630
#   Epoch 300, Batch 46/160 → Batch Loss: 0.0731
#   Epoch 300, Batch 47/160 → Batch Loss: 0.0776
#   Epoch 300, Batch 48/160 → Batch Loss: -0.0039
#   Epoch 300, Batch 49/160 → Batch Loss: 0.0385
#   Epoch 300, Batch 50/160 → Batch Loss: 0.0569
#   Epoch 300, Batch 51/160 → Batch Loss: 0.0423
#   Epoch 300, Batch 52/160 → Batch Loss: 0.1087
#   Epoch 300, Batch 53/160 → Batch Loss: 0.0192
#   Epoch 300, Batch 54/160 → Batch Loss: 0.0118
#   Epoch 300, Batch 55/160 → Batch Loss: 0.0349
#   Epoch 300, Batch 56/160 → Batch Loss: 0.0275
#   Epoch 300, Batch 57/160 → Batch Loss: 0.0176
#   Epoch 300, Batch 58/160 → Batch Loss: 0.0577
#   Epoch 300, Batch 59/160 → Batch Loss: -0.0174
#   Epoch 300, Batch 60/160 → Batch Loss: -0.0081
#   Epoch 300, Batch 61/160 → Batch Loss: -0.0033
#   Epoch 300, Batch 62/160 → Batch Loss: -0.0077
#   Epoch 300, Batch 63/160 → Batch Loss: 0.0069
#   Epoch 300, Batch 64/160 → Batch Loss: -0.0836
#   Epoch 300, Batch 65/160 → Batch Loss: 0.0219
#   Epoch 300, Batch 66/160 → Batch Loss: -0.0266
#   Epoch 300, Batch 67/160 → Batch Loss: -0.0054
#   Epoch 300, Batch 68/160 → Batch Loss: 0.0851
#   Epoch 300, Batch 69/160 → Batch Loss: 0.0622
#   Epoch 300, Batch 70/160 → Batch Loss: 0.0385
#   Epoch 300, Batch 71/160 → Batch Loss: 0.0052
#   Epoch 300, Batch 72/160 → Batch Loss: 0.0452
#   Epoch 300, Batch 73/160 → Batch Loss: -0.0030
#   Epoch 300, Batch 74/160 → Batch Loss: -0.0185
#   Epoch 300, Batch 75/160 → Batch Loss: 0.0148
#   Epoch 300, Batch 76/160 → Batch Loss: 0.0128
#   Epoch 300, Batch 77/160 → Batch Loss: 0.0519
#   Epoch 300, Batch 78/160 → Batch Loss: 0.0010
#   Epoch 300, Batch 79/160 → Batch Loss: 0.0808
#   Epoch 300, Batch 80/160 → Batch Loss: 0.2913
#   Epoch 300, Batch 81/160 → Batch Loss: 0.0566
#   Epoch 300, Batch 82/160 → Batch Loss: 0.0781
#   Epoch 300, Batch 83/160 → Batch Loss: 0.0021
#   Epoch 300, Batch 84/160 → Batch Loss: 0.0189
#   Epoch 300, Batch 85/160 → Batch Loss: 0.1421
#   Epoch 300, Batch 86/160 → Batch Loss: 0.0513
#   Epoch 300, Batch 87/160 → Batch Loss: -0.0345
#   Epoch 300, Batch 88/160 → Batch Loss: 0.0720
#   Epoch 300, Batch 89/160 → Batch Loss: 0.0738
#   Epoch 300, Batch 90/160 → Batch Loss: 0.0045
#   Epoch 300, Batch 91/160 → Batch Loss: 0.0475
#   Epoch 300, Batch 92/160 → Batch Loss: 0.0176
#   Epoch 300, Batch 93/160 → Batch Loss: 0.0092
#   Epoch 300, Batch 94/160 → Batch Loss: 0.0364
#   Epoch 300, Batch 95/160 → Batch Loss: -0.0437
#   Epoch 300, Batch 96/160 → Batch Loss: 0.0882
#   Epoch 300, Batch 97/160 → Batch Loss: -0.0187
#   Epoch 300, Batch 98/160 → Batch Loss: 0.0128
#   Epoch 300, Batch 99/160 → Batch Loss: 0.0504
#   Epoch 300, Batch 100/160 → Batch Loss: -0.0454
#   Epoch 300, Batch 101/160 → Batch Loss: 0.0599
#   Epoch 300, Batch 102/160 → Batch Loss: -0.0044
#   Epoch 300, Batch 103/160 → Batch Loss: 0.0156
#   Epoch 300, Batch 104/160 → Batch Loss: -0.0066
#   Epoch 300, Batch 105/160 → Batch Loss: 0.0862
#   Epoch 300, Batch 106/160 → Batch Loss: 0.0537
#   Epoch 300, Batch 107/160 → Batch Loss: 0.0486
#   Epoch 300, Batch 108/160 → Batch Loss: 0.0125
#   Epoch 300, Batch 109/160 → Batch Loss: 0.0606
#   Epoch 300, Batch 110/160 → Batch Loss: 0.1105
#   Epoch 300, Batch 111/160 → Batch Loss: 0.0307
#   Epoch 300, Batch 112/160 → Batch Loss: 0.0520
#   Epoch 300, Batch 113/160 → Batch Loss: -0.0320
#   Epoch 300, Batch 114/160 → Batch Loss: 0.0701
#   Epoch 300, Batch 115/160 → Batch Loss: 0.0089
#   Epoch 300, Batch 116/160 → Batch Loss: 0.0598
#   Epoch 300, Batch 117/160 → Batch Loss: 0.0028
#   Epoch 300, Batch 118/160 → Batch Loss: -0.0003
#   Epoch 300, Batch 119/160 → Batch Loss: 0.0282
#   Epoch 300, Batch 120/160 → Batch Loss: 0.0767
#   Epoch 300, Batch 121/160 → Batch Loss: -0.0315
#   Epoch 300, Batch 122/160 → Batch Loss: -0.0169
#   Epoch 300, Batch 123/160 → Batch Loss: 0.0202
#   Epoch 300, Batch 124/160 → Batch Loss: 0.0331
#   Epoch 300, Batch 125/160 → Batch Loss: 0.0120
#   Epoch 300, Batch 126/160 → Batch Loss: 0.0948
#   Epoch 300, Batch 127/160 → Batch Loss: 0.0252
#   Epoch 300, Batch 128/160 → Batch Loss: 0.0449
#   Epoch 300, Batch 129/160 → Batch Loss: -0.0164
#   Epoch 300, Batch 130/160 → Batch Loss: 0.0028
#   Epoch 300, Batch 131/160 → Batch Loss: 0.0766
#   Epoch 300, Batch 132/160 → Batch Loss: -0.0078
#   Epoch 300, Batch 133/160 → Batch Loss: 0.0416
#   Epoch 300, Batch 134/160 → Batch Loss: 0.0136
#   Epoch 300, Batch 135/160 → Batch Loss: 0.0898
#   Epoch 300, Batch 136/160 → Batch Loss: -0.0434
#   Epoch 300, Batch 137/160 → Batch Loss: 0.0215
#   Epoch 300, Batch 138/160 → Batch Loss: 0.1296
#   Epoch 300, Batch 139/160 → Batch Loss: -0.0076
#   Epoch 300, Batch 140/160 → Batch Loss: 0.0489
#   Epoch 300, Batch 141/160 → Batch Loss: 0.0756
#   Epoch 300, Batch 142/160 → Batch Loss: 0.0816
#   Epoch 300, Batch 143/160 → Batch Loss: 0.0354
#   Epoch 300, Batch 144/160 → Batch Loss: -0.0478
#   Epoch 300, Batch 145/160 → Batch Loss: 0.0328
#   Epoch 300, Batch 146/160 → Batch Loss: -0.0080
#   Epoch 300, Batch 147/160 → Batch Loss: 0.0132
#   Epoch 300, Batch 148/160 → Batch Loss: 0.0297
#   Epoch 300, Batch 149/160 → Batch Loss: -0.0049
#   Epoch 300, Batch 150/160 → Batch Loss: 0.0503
#   Epoch 300, Batch 151/160 → Batch Loss: -0.0261
#   Epoch 300, Batch 152/160 → Batch Loss: 0.0257
#   Epoch 300, Batch 153/160 → Batch Loss: -0.0020
#   Epoch 300, Batch 154/160 → Batch Loss: 0.3447
#   Epoch 300, Batch 155/160 → Batch Loss: -0.0353
#   Epoch 300, Batch 156/160 → Batch Loss: 0.0619
#   Epoch 300, Batch 157/160 → Batch Loss: 0.0488
#   Epoch 300, Batch 158/160 → Batch Loss: 0.0235
#   Epoch 300, Batch 159/160 → Batch Loss: 0.0577
#   Epoch 300, Batch 160/160 → Batch Loss: 0.0523

# %%
torch.save({
    'w1': w1,
    'w2a': w2a,
    'w2c': w2c,
    'log_std': log_std
}, 'MLP_feature_v2.pth')

# %%
# Plot results after training
epochs_range = list(range(1, len(actor_loss_hist)+1))

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4), sharex=True)

# 5.3.1 Actor Loss Over Epochs
ax1.plot(epochs_range, actor_loss_hist, marker='o')
ax1.set_title("Actor Loss Over Epochs")
ax1.set_xlabel("Epoch")
ax1.set_ylabel("Actor Loss")
ax1.grid(True)

# 5.3.3 Log-Probability of Actions
ax2.plot(epochs_range, logprob_hist, marker='o', color='tab:green')
ax2.set_title("Average Log-Probability Over Epochs")
ax2.set_xlabel("Epoch")
ax2.set_ylabel("Avg. Log-Probability")
ax2.grid(True)

plt.tight_layout()
plt.savefig("MLP_Features/actor_loss_and_logprob5.png", dpi=300)
plt.show()

# %% [markdown]
# ### Trading Environment

# %%
class MultiStockEnvironment:
    def __init__(self, data, window_size, initial_cash=10000):
        self.data = data  # this is now the full data dict with all features
        self.window_size  = window_size
        self.initial_cash = float(initial_cash)
        self.tickers      = list(data.keys())
        self.reset()

    def reset(self):
        self.t = 0
        self.cash = self.initial_cash
        self.holdings = {t: 0.0 for t in self.tickers}
        self.portfolio_values = [self.initial_cash]
        self.done = False

        return {
            t: np.column_stack([
                self.data[t]["norm"][0:self.window_size],
                self.data[t]["ema"][0:self.window_size],
                self.data[t]["rsi"][0:self.window_size],
                self.data[t]["macd"][0:self.window_size],
                self.data[t]["bb_upper"][0:self.window_size],
                self.data[t]["bb_lower"][0:self.window_size],
            ])
            for t in self.tickers
        }

    def step(self, actions):
        # Liquidate negatives
        freed_cash = 0.0
        for t in self.tickers:
            if actions[t] < 0 and self.holdings[t] > 0:
                price = self.data[t]["raw"][self.t + self.window_size].item()
                freed_cash += self.holdings[t] * price
                self.holdings[t] = 0.0
        self.cash += freed_cash

        # Allocate positives
        pos_actions = {t: actions[t] for t in self.tickers if actions[t] > 0}
        total_pos   = sum(pos_actions.values())
        if total_pos > 0 and self.cash > 0:
            for t, a in pos_actions.items():
                weight = a / total_pos
                price = self.data[t]["raw"][self.t + self.window_size].item()
                buy_amount = self.cash * weight
                self.holdings[t] += buy_amount / price
            self.cash = 0.0

        # Compute portfolio value
        pv = self.cash
        for t in self.tickers:
            price = self.data[t]["raw"][self.t + self.window_size].item()
            pv += self.holdings[t] * price
        self.portfolio_values.append(pv)

        # Advance time
        self.t += 1
        if self.t + self.window_size >= len(self.data[self.tickers[0]]["raw"]):
            self.done = True

        # Next state
        next_states = None
        if not self.done:
            next_states = {
                t: np.column_stack([
                    self.data[t]["norm"][self.t : self.t + self.window_size],
                    self.data[t]["ema"][self.t : self.t + self.window_size],
                    self.data[t]["rsi"][self.t : self.t + self.window_size],
                    self.data[t]["macd"][self.t : self.t + self.window_size],
                    self.data[t]["bb_upper"][self.t : self.t + self.window_size],
                    self.data[t]["bb_lower"][self.t : self.t + self.window_size],
                ])
                for t in self.tickers
            }

        return next_states, pv, self.done, {}

# %% [markdown]
# ### buy and hold

# %%
class BuyAndHoldEnvironment:
    def __init__(self, raw_prices, initial_cash=10000):
        self.raw_prices = raw_prices
        self.initial_cash = initial_cash
        self.portfolio_values = []

    def run(self, start_index=10):
        # stack into shape (T,5)
        prices = np.stack([self.raw_prices[t] for t in tickers], axis=1)
        # equal allocation
        alloc = self.initial_cash / len(tickers)
        init_p = prices[start_index]            
        shares = alloc / init_p                 
        # build PV curve
        for p in prices[start_index+1:]:
            self.portfolio_values.append((shares * p).sum())

# %% [markdown]
# ### Simulate Agent with the trained MLP once

# %%
# Precompute price normalization stats (still needed for logging only)
mean_price = {t: raw_prices[t].mean() for t in tickers}
std_price  = {t: raw_prices[t].std()  for t in tickers}

# Instantiate the environment with full data (not just raw_prices)
env = MultiStockEnvironment(data, window_size=state_dim)
state_dict = env.reset()

day = 0
print("Starting multi-stock simulation...\n")

while not env.done:
    # Sample actions from current state
    actions = {}
    trades  = {}
    for t in tickers:
        win = state_dict[t]  # shape: (state_dim, 6)

        # Already normalized in data — just flatten
        st = torch.tensor(win, dtype=torch.float32).view(1, -1)  # shape: (1, 30)

        a_tensor, _ = get_action(st, w1, w2a, log_std)
        a_val       = a_tensor.item()
        actions[t]  = a_val

        if   a_val > 0 and env.holdings[t] == 0:
            trades[t] = "BUY"
        elif a_val < 0 and env.holdings[t] > 0:
            trades[t] = "SELL"
        else:
            trades[t] = "HOLD"

    # Step the environment
    next_states, port_val, done, _ = env.step(actions)

    # Log values
    cash = float(env.cash)
    prices = {t: float(raw_prices[t][day + state_dim]) for t in tickers}
    held   = {t: float(env.holdings[t]) for t in tickers}

    # Print summary and per-ticker details
    print(f"Day {day}: Cash = {cash:.2f}, Portfolio = {port_val:.2f}")
    for t in tickers:
        print(f"  {t:>6s} | Price = {prices[t]:6.2f} | "
              f"Action = {actions[t]:6.4f} | Trade = {trades[t]:>4s} | "
              f"Held = {held[t]:6.4f}")
    print("-" * 60)

    # advance
    state_dict = next_states
    day += 1

print(f"\nDone. Final portfolio value: {env.portfolio_values[-1]:.2f}")
# Out:
# Starting multi-stock simulation...
#
# Day 0: Cash = 0.00, Portfolio = 10000.00
#     AAPL | Price =  74.96 | Action = 3.4299 | Trade =  BUY | Held = 18.3365
#     MSFT | Price = 154.73 | Action = 3.4970 | Trade =  BUY | Held = 8.3974
#    GOOGL | Price =  70.65 | Action = 3.0922 | Trade =  BUY | Held = 17.7211
#     META | Price = 217.28 | Action = 1.2854 | Trade =  BUY | Held = 2.5781
#     AMZN | Price =  95.05 | Action = 3.8654 | Trade =  BUY | Held = 15.8716
#     TSLA | Price =  32.09 | Action = 6.8811 | Trade =  BUY | Held = 58.0086
#     NVDA | Price =   6.05 | Action = 1.7064 | Trade =  BUY | Held = 113.4861
# ------------------------------------------------------------
# Day 1: Cash = 0.00, Portfolio = 10001.12
#     AAPL | Price =  75.13 | Action = 1.3004 | Trade = HOLD | Held = 18.3365
#     MSFT | Price = 154.01 | Action = 6.5000 | Trade = HOLD | Held = 8.3974
#    GOOGL | Price =  71.11 | Action = 2.9413 | Trade = HOLD | Held = 17.7211
#     META | Price = 217.04 | Action = 0.5389 | Trade = HOLD | Held = 2.5781
#     AMZN | Price =  94.16 | Action = 5.1240 | Trade = HOLD | Held = 15.8716
#     TSLA | Price =  31.88 | Action = 5.1965 | Trade = HOLD | Held = 58.0086
#     NVDA | Price =   6.08 | Action = 1.8759 | Trade = HOLD | Held = 113.4861
# ------------------------------------------------------------
# Day 2: Cash = 0.00, Portfolio = 10239.64
#     AAPL | Price =  76.74 | Action = 4.5521 | Trade = HOLD | Held = 18.3365
#     MSFT | Price = 155.86 | Action = 5.1262 | Trade = HOLD | Held = 8.3974
#    GOOGL | Price =  71.66 | Action = 0.7500 | Trade = HOLD | Held = 17.7211
#     META | Price = 220.87 | Action = 2.0750 | Trade = HOLD | Held = 2.5781
#     AMZN | Price =  94.57 | Action = 4.1698 | Trade = HOLD | Held = 15.8716
#     TSLA | Price =  34.99 | Action = 4.0358 | Trade = HOLD | Held = 58.0086
#     NVDA | Price =   6.27 | Action = 1.4869 | Trade = HOLD | Held = 113.4861
# ------------------------------------------------------------
# Day 3: Cash = 0.00, Portfolio = 10222.32
#     AAPL | Price =  75.70 | Action = 3.2424 | Trade = HOLD | Held = 18.3365
#     MSFT | Price = 154.76 | Action = 2.7124 | Trade = HOLD | Held = 8.3974
#    GOOGL | Price =  71.19 | Action = 1.0069 | Trade = HOLD | Held = 17.7211
#     META | Price = 218.03 | Action = 2.0767 | Trade = HOLD | Held = 2.5781
#     AMZN | Price =  93.47 | Action = 5.5513 | Trade = HOLD | Held = 15.8716
#     TSLA | Price =  35.86 | Action = 5.0934 | Trade = HOLD | Held = 58.0086
#     NVDA | Price =   6.16 | Action = 5.2401 | Trade = HOLD | Held = 113.4861
# ------------------------------------------------------------
# Day 4: Cash = 0.00, Portfolio = 10268.00
#     AAPL | Price =  75.38 | Action = 4.4004 | Trade = HOLD | Held = 18.3365
#     MSFT | Price = 155.77 | Action = 4.1992 | Trade = HOLD | Held = 8.3974
#    GOOGL | Price =  71.62 | Action = 2.8262 | Trade = HOLD | Held = 17.7211
#     META | Price = 220.11 | Action = 1.4003 | Trade = HOLD | Held = 2.5781
#     AMZN | Price =  93.10 | Action = 5.3618 | Trade = HOLD | Held = 15.8716
#     TSLA | Price =  34.57 | Action = 4.1055 | Trade = HOLD | Held = 58.0086
#     NVDA | Price =   6.11 | Action = 3.1932 | Trade = HOLD | Held = 113.4861
# ------------------------------------------------------------
# Day 5: Cash = 0.00, Portfolio = 10380.05
#     AAPL | Price =  76.32 | Action = 1.2836 | Trade = HOLD | Held = 18.3365
#     MSFT | Price = 158.62 | Action = 6.3255 | Trade = HOLD | Held = 8.3974
#    GOOGL | Price =  72.16 | Action = 1.8981 | Trade = HOLD | Held = 17.7211
#     META | Price = 220.73 | Action = 1.1872 | Trade = HOLD | Held = 2.5781
#     AMZN | Price =  93.90 | Action = 3.4665 | Trade = HOLD | Held = 15.8716
#     TSLA | Price =  34.23 | Action = 4.7536 | Trade = HOLD | Held = 58.0086
#     NVDA | Price =   6.20 | Action = 2.1226 | Trade = HOLD | Held = 113.4861
# ------------------------------------------------------------
# Day 6: Cash = 0.00, Portfolio = 10427.38
#     AAPL | Price =  77.17 | Action = 3.7428 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 159.51 | Action = 4.3257 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  73.62 | Action = 0.1641 | Trade = HOLD | Held = 17.7841
#     META | Price = 221.10 | Action = -0.5398 | Trade = SELL | Held = 0.0000
#     AMZN | Price =  93.24 | Action = 4.3533 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  34.03 | Action = 3.8897 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   6.21 | Action = 2.4592 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 7: Cash = 0.00, Portfolio = 10688.41
#     AAPL | Price =  76.64 | Action = 1.8851 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 158.94 | Action = 3.2175 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  73.76 | Action = 0.7693 | Trade = HOLD | Held = 17.7841
#     META | Price = 220.40 | Action = 0.8646 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  94.60 | Action = 6.4472 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  36.48 | Action = 5.5892 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   6.17 | Action = 4.2796 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 8: Cash = 0.00, Portfolio = 11024.87
#     AAPL | Price =  76.92 | Action = 4.4876 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 158.17 | Action = 6.2080 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  73.84 | Action = 3.9295 | Trade = HOLD | Held = 17.7841
#     META | Price = 220.28 | Action = 1.7236 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  94.37 | Action = 4.6293 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  37.97 | Action = 3.3068 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   6.23 | Action = 2.9732 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 9: Cash = 0.00, Portfolio = 10871.86
#     AAPL | Price =  77.29 | Action = 5.1309 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 159.15 | Action = 5.0494 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  73.88 | Action = 4.6517 | Trade = HOLD | Held = 17.7841
#     META | Price = 218.73 | Action = 0.1349 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  94.23 | Action = 6.3133 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  38.15 | Action = 3.7198 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   6.29 | Action = 3.7231 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 10: Cash = 0.00, Portfolio = 10669.40
#     AAPL | Price =  77.06 | Action = 2.2534 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 157.54 | Action = 2.1614 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  72.96 | Action = 0.7097 | Trade = HOLD | Held = 17.7841
#     META | Price = 216.92 | Action = 0.2186 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  93.08 | Action = 7.0628 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  37.65 | Action = 4.1921 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   6.24 | Action = 3.3774 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 11: Cash = 0.00, Portfolio = 10067.68
#     AAPL | Price =  74.80 | Action = 1.7815 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 154.91 | Action = 4.5152 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  71.25 | Action = 2.0550 | Trade = HOLD | Held = 17.7841
#     META | Price = 213.86 | Action = 1.3659 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  91.42 | Action = 5.0880 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  37.20 | Action = 4.4876 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   5.98 | Action = 4.7778 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 12: Cash = 0.00, Portfolio = 9763.64
#     AAPL | Price =  76.91 | Action = 2.9038 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 157.94 | Action = 4.3677 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  72.18 | Action = 2.1708 | Trade = HOLD | Held = 17.7841
#     META | Price = 216.77 | Action = 2.2033 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  92.66 | Action = 5.9256 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  37.79 | Action = 3.5958 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   6.17 | Action = 5.7222 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 13: Cash = 0.00, Portfolio = 9745.90
#     AAPL | Price =  78.52 | Action = 3.3172 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 160.41 | Action = 4.6256 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  72.49 | Action = 2.6462 | Trade = HOLD | Held = 17.7841
#     META | Price = 222.18 | Action = 0.9561 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  92.90 | Action = 6.3915 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  38.73 | Action = 4.1840 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   6.11 | Action = 3.5830 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 14: Cash = 0.00, Portfolio = 8955.98
#     AAPL | Price =  78.41 | Action = 4.5127 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 164.93 | Action = 4.3875 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  72.37 | Action = 0.8536 | Trade = HOLD | Held = 17.7841
#     META | Price = 208.55 | Action = 1.3259 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  93.53 | Action = 2.4039 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  42.72 | Action = 2.5501 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   6.12 | Action = 3.9148 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 15: Cash = 0.00, Portfolio = 9019.19
#     AAPL | Price =  74.93 | Action = 2.3315 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 162.50 | Action = 0.6167 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  71.30 | Action = 2.7179 | Trade = HOLD | Held = 17.7841
#     META | Price = 200.96 | Action = 0.2965 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 100.44 | Action = 3.2170 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  43.37 | Action = 3.3352 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   5.89 | Action = 4.2927 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 16: Cash = 0.00, Portfolio = 9659.14
#     AAPL | Price =  74.73 | Action = 2.6327 | Trade = HOLD | Held = 19.7141
#     MSFT | Price = 166.46 | Action = 1.6208 | Trade = HOLD | Held = 9.1070
#    GOOGL | Price =  73.78 | Action = 2.4653 | Trade = HOLD | Held = 17.7841
#     META | Price = 203.23 | Action = 3.3024 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 100.21 | Action = 0.4921 | Trade = HOLD | Held = 17.0553
#     TSLA | Price =  52.00 | Action = 1.8870 | Trade = HOLD | Held = 60.1254
#     NVDA | Price =   5.98 | Action = 3.9481 | Trade = HOLD | Held = 123.3811
# ------------------------------------------------------------
# Day 17: Cash = 0.00, Portfolio = 9435.39
#     AAPL | Price =  77.20 | Action = 3.2194 | Trade = HOLD | Held = 22.8897
#     MSFT | Price = 171.94 | Action = 3.3971 | Trade = HOLD | Held = 10.6012
#    GOOGL | Price =  71.93 | Action = -0.7877 | Trade = SELL | Held = 0.0000
#     META | Price = 208.85 | Action = 0.8068 | Trade =  BUY | Held = 0.3020
#     AMZN | Price = 102.48 | Action = 2.7790 | Trade = HOLD | Held = 19.0718
#     TSLA | Price =  59.14 | Action = 3.4559 | Trade = HOLD | Held = 64.9411
#     NVDA | Price =   6.15 | Action = 3.4354 | Trade = HOLD | Held = 159.3054
# ------------------------------------------------------------
# Day 18: Cash = 0.00, Portfolio = 9727.89
#     AAPL | Price =  77.82 | Action = 1.8640 | Trade = HOLD | Held = 25.6548
#     MSFT | Price = 171.73 | Action = -0.1409 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  71.96 | Action = 2.2526 | Trade =  BUY | Held = 3.5708
#     META | Price = 209.12 | Action = 1.3404 | Trade = HOLD | Held = 1.0674
#     AMZN | Price = 101.99 | Action = 4.1263 | Trade = HOLD | Held = 23.6238
#     TSLA | Price =  48.98 | Action = 2.0821 | Trade = HOLD | Held = 69.4825
#     NVDA | Price =   6.24 | Action = 4.2141 | Trade = HOLD | Held = 224.1125
# ------------------------------------------------------------
# Day 19: Cash = 0.00, Portfolio = 9408.43
#     AAPL | Price =  78.73 | Action = 4.9261 | Trade = HOLD | Held = 25.6548
#     MSFT | Price = 175.29 | Action = 1.2785 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  73.45 | Action = 2.3458 | Trade = HOLD | Held = 3.5708
#     META | Price = 209.86 | Action = 2.5016 | Trade = HOLD | Held = 1.0674
#     AMZN | Price = 102.51 | Action = 1.5683 | Trade = HOLD | Held = 23.6238
#     TSLA | Price =  49.93 | Action = 4.2494 | Trade = HOLD | Held = 69.4825
#     NVDA | Price =   6.33 | Action = 3.5541 | Trade = HOLD | Held = 224.1125
# ------------------------------------------------------------
# Day 20: Cash = 0.00, Portfolio = 9211.38
#     AAPL | Price =  77.66 | Action = 1.4591 | Trade = HOLD | Held = 25.6548
#     MSFT | Price = 175.54 | Action = 4.3006 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  73.60 | Action = 2.7807 | Trade = HOLD | Held = 3.5708
#     META | Price = 211.33 | Action = 1.0574 | Trade = HOLD | Held = 1.0674
#     AMZN | Price = 103.96 | Action = 3.0240 | Trade = HOLD | Held = 23.6238
#     TSLA | Price =  49.87 | Action = 3.4651 | Trade = HOLD | Held = 69.4825
#     NVDA | Price =   6.26 | Action = 3.0458 | Trade = HOLD | Held = 224.1125
# ------------------------------------------------------------
# Day 21: Cash = 0.00, Portfolio = 8366.58
#     AAPL | Price =  78.03 | Action = 3.0875 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 180.13 | Action = 3.0900 | Trade =  BUY | Held = 0.2114
#    GOOGL | Price =  75.07 | Action = 3.6760 | Trade = HOLD | Held = 4.1700
#     META | Price = 212.06 | Action = -0.1799 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 106.70 | Action = 2.6905 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  51.42 | Action = 2.7224 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.55 | Action = 2.9930 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 22: Cash = 0.00, Portfolio = 8875.36
#     AAPL | Price =  77.56 | Action = 3.9180 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 176.06 | Action = 2.3558 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  75.14 | Action = 3.1969 | Trade = HOLD | Held = 4.1700
#     META | Price = 206.22 | Action = 2.6767 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 107.54 | Action = 3.0756 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  51.63 | Action = 1.2041 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.67 | Action = 3.1440 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 23: Cash = 0.00, Portfolio = 8577.63
#     AAPL | Price =  79.40 | Action = 3.3375 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 176.32 | Action = 2.3513 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  75.57 | Action = 2.1209 | Trade = HOLD | Held = 4.1700
#     META | Price = 209.77 | Action = 3.2626 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 108.00 | Action = 1.3929 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  51.15 | Action = 3.6213 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.78 | Action = 2.2826 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 24: Cash = 0.00, Portfolio = 7692.56
#     AAPL | Price =  78.84 | Action = 3.6204 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 175.36 | Action = 0.7045 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  75.31 | Action = 3.7848 | Trade = HOLD | Held = 4.1700
#     META | Price = 212.14 | Action = 1.7024 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 107.49 | Action = 5.0306 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  53.60 | Action = 1.7688 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.74 | Action = 2.9090 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 25: Cash = 0.00, Portfolio = 8110.80
#     AAPL | Price =  78.86 | Action = 3.7263 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 176.93 | Action = 3.7778 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  75.58 | Action = 2.7033 | Trade = HOLD | Held = 4.1700
#     META | Price = 213.18 | Action = 3.9232 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 106.74 | Action = 2.9118 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  53.34 | Action = 1.2473 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   7.21 | Action = 1.1601 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 26: Cash = 0.00, Portfolio = 7007.10
#     AAPL | Price =  77.41 | Action = 2.3985 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 178.72 | Action = 2.5335 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  75.61 | Action = 4.3509 | Trade = HOLD | Held = 4.1700
#     META | Price = 216.78 | Action = 3.4278 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 107.78 | Action = 2.9102 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  57.23 | Action = 2.2484 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   7.38 | Action = 1.7899 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 27: Cash = 0.00, Portfolio = 7277.64
#     AAPL | Price =  78.54 | Action = 4.9070 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 179.26 | Action = 3.7941 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  75.88 | Action = 4.6982 | Trade = HOLD | Held = 4.1700
#     META | Price = 216.47 | Action = 4.1965 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 108.51 | Action = 2.3989 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  61.16 | Action = 1.4730 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   7.83 | Action = 1.1347 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 28: Cash = 0.00, Portfolio = 6853.10
#     AAPL | Price =  77.73 | Action = 2.8769 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 176.52 | Action = 3.0409 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  75.49 | Action = 3.4250 | Trade = HOLD | Held = 4.1700
#     META | Price = 213.57 | Action = 2.8420 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 107.65 | Action = 3.2497 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  59.96 | Action = 2.9479 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   7.68 | Action = 2.2112 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 29: Cash = 0.00, Portfolio = 7275.23
#     AAPL | Price =  75.97 | Action = 1.7600 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 170.94 | Action = 4.6234 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  73.82 | Action = 4.5520 | Trade = HOLD | Held = 4.1700
#     META | Price = 209.19 | Action = 4.1941 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 104.80 | Action = 3.4536 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  60.07 | Action = 3.4261 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   7.32 | Action = 2.3781 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 30: Cash = 0.00, Portfolio = 7083.24
#     AAPL | Price =  72.36 | Action = 4.6254 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 163.57 | Action = 3.3268 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  70.66 | Action = 5.1537 | Trade = HOLD | Held = 4.1700
#     META | Price = 199.78 | Action = 4.7323 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 100.46 | Action = 2.4671 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  55.59 | Action = 3.4534 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.80 | Action = 1.6451 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 31: Cash = 0.00, Portfolio = 7188.21
#     AAPL | Price =  69.91 | Action = 5.0370 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 160.87 | Action = 2.1002 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  68.99 | Action = 6.0080 | Trade = HOLD | Held = 4.1700
#     META | Price = 195.85 | Action = 3.9715 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  98.64 | Action = 1.2410 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  53.33 | Action = 3.9981 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.52 | Action = 0.3142 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 32: Cash = 0.00, Portfolio = 7932.50
#     AAPL | Price =  71.02 | Action = 3.3391 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 162.88 | Action = 4.5159 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  69.19 | Action = 4.5083 | Trade = HOLD | Held = 4.1700
#     META | Price = 196.27 | Action = 4.3957 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  98.98 | Action = 3.6819 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  51.92 | Action = 2.9222 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.66 | Action = 2.8630 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 33: Cash = 0.00, Portfolio = 7992.67
#     AAPL | Price =  66.38 | Action = 3.8931 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 151.41 | Action = 4.4564 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  65.43 | Action = 4.6181 | Trade = HOLD | Held = 4.1700
#     META | Price = 188.86 | Action = 2.8936 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  94.21 | Action = 3.5808 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  45.27 | Action = 3.9635 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.29 | Action = 2.7440 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 34: Cash = 0.00, Portfolio = 8186.86
#     AAPL | Price =  66.34 | Action = 4.0204 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 155.07 | Action = 5.4883 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  66.64 | Action = 3.4245 | Trade = HOLD | Held = 4.1700
#     META | Price = 191.57 | Action = 3.4209 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  94.19 | Action = 3.3699 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  44.53 | Action = 2.9319 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.73 | Action = 1.7121 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 35: Cash = 0.00, Portfolio = 7950.30
#     AAPL | Price =  72.51 | Action = 4.6473 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 165.39 | Action = 2.1834 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  68.99 | Action = 3.6775 | Trade = HOLD | Held = 4.1700
#     META | Price = 195.52 | Action = 3.5550 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  97.70 | Action = 5.2972 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  49.57 | Action = 2.5814 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.89 | Action = 2.6806 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 36: Cash = 0.00, Portfolio = 8097.24
#     AAPL | Price =  70.21 | Action = 3.6362 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 157.47 | Action = 2.9557 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  66.57 | Action = 2.0170 | Trade = HOLD | Held = 4.1700
#     META | Price = 185.02 | Action = 4.7227 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  95.45 | Action = 4.0051 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  49.70 | Action = 5.2529 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.62 | Action = 0.8587 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 37: Cash = 0.00, Portfolio = 8170.59
#     AAPL | Price =  73.47 | Action = 5.6484 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 163.25 | Action = 3.3512 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  68.75 | Action = 3.0791 | Trade = HOLD | Held = 4.1700
#     META | Price = 190.86 | Action = 3.7424 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  98.79 | Action = 2.8389 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  49.97 | Action = 2.6946 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   7.09 | Action = 2.9121 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 38: Cash = 0.00, Portfolio = 7706.41
#     AAPL | Price =  71.09 | Action = 3.8170 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 159.15 | Action = 6.2087 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  65.43 | Action = 3.8179 | Trade = HOLD | Held = 4.1700
#     META | Price = 184.30 | Action = 2.5781 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  96.20 | Action = 3.3288 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  48.30 | Action = 3.5027 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.81 | Action = 2.1367 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 39: Cash = 0.00, Portfolio = 7692.98
#     AAPL | Price =  70.14 | Action = 3.2234 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 154.65 | Action = 2.7991 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  64.48 | Action = 2.5214 | Trade = HOLD | Held = 4.1700
#     META | Price = 180.24 | Action = 1.1616 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  95.05 | Action = 3.4094 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  46.90 | Action = 2.0332 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.63 | Action = 3.2103 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 40: Cash = 0.00, Portfolio = 7704.19
#     AAPL | Price =  64.59 | Action = 3.0544 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 144.17 | Action = 2.1819 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  60.50 | Action = 1.5224 | Trade = HOLD | Held = 4.1700
#     META | Price = 168.70 | Action = 2.2079 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  90.03 | Action = 4.7125 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  40.53 | Action = 3.1718 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.11 | Action = 1.0890 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 41: Cash = 0.00, Portfolio = 8276.72
#     AAPL | Price =  69.25 | Action = 3.7667 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 154.03 | Action = 4.4447 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  63.46 | Action = 3.4508 | Trade = HOLD | Held = 4.1700
#     META | Price = 177.35 | Action = 2.8606 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  94.59 | Action = 4.2773 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  43.02 | Action = 1.7167 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.50 | Action = 3.4504 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 42: Cash = 0.00, Portfolio = 8356.87
#     AAPL | Price =  66.84 | Action = 4.0970 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 147.05 | Action = 4.5660 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  60.26 | Action = 2.7731 | Trade = HOLD | Held = 4.1700
#     META | Price = 169.44 | Action = 2.0288 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  91.04 | Action = 4.4825 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  42.28 | Action = 2.7233 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.14 | Action = 3.9680 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 43: Cash = 0.00, Portfolio = 8502.94
#     AAPL | Price =  60.24 | Action = 2.9868 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 133.11 | Action = 3.3304 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  55.31 | Action = 2.0957 | Trade = HOLD | Held = 4.1700
#     META | Price = 153.75 | Action = 2.6091 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  83.83 | Action = 5.3511 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  37.37 | Action = 3.7252 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   5.39 | Action = 2.6146 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 44: Cash = 0.00, Portfolio = 8604.91
#     AAPL | Price =  67.46 | Action = 4.3859 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 152.03 | Action = 3.6042 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  60.42 | Action = 4.1883 | Trade = HOLD | Held = 4.1700
#     META | Price = 169.48 | Action = 3.8020 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  89.25 | Action = 4.0921 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  36.44 | Action = 2.6388 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.00 | Action = 5.5198 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 45: Cash = 0.00, Portfolio = 9193.82
#     AAPL | Price =  58.78 | Action = 0.2400 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 129.62 | Action = 3.0518 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  53.39 | Action = 4.5508 | Trade = HOLD | Held = 4.1700
#     META | Price = 145.33 | Action = 1.9797 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  84.46 | Action = 4.2120 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  29.67 | Action = 3.6334 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   4.89 | Action = 3.9951 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 46: Cash = 0.00, Portfolio = 9787.25
#     AAPL | Price =  61.36 | Action = 4.3284 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 140.29 | Action = 3.5625 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  55.64 | Action = 3.7333 | Trade = HOLD | Held = 4.1700
#     META | Price = 148.72 | Action = 2.6955 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  90.39 | Action = 5.0682 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  28.68 | Action = 2.6750 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   5.41 | Action = 2.5627 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_1984/1593004457.py:38: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   prices = {t: float(raw_prices[t][day + state_dim]) for t in tickers}
# Day 47: Cash = 0.00, Portfolio = 9873.27
#     AAPL | Price =  59.86 | Action = 4.3125 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 134.39 | Action = 7.8844 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  54.30 | Action = 4.8996 | Trade = HOLD | Held = 4.1700
#     META | Price = 146.27 | Action = 2.4705 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  91.50 | Action = 3.4181 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  24.08 | Action = 4.8849 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   5.05 | Action = 2.7025 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 48: Cash = 0.00, Portfolio = 10159.83
#     AAPL | Price =  59.40 | Action = 4.1491 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 136.60 | Action = 3.0956 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  55.32 | Action = 4.8573 | Trade = HOLD | Held = 4.1700
#     META | Price = 152.41 | Action = 3.5486 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  94.05 | Action = 4.7928 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  28.51 | Action = 5.2585 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   5.30 | Action = 3.1750 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 49: Cash = 0.00, Portfolio = 10127.28
#     AAPL | Price =  55.63 | Action = 3.7061 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 131.47 | Action = 6.0019 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  53.16 | Action = 3.8078 | Trade = HOLD | Held = 4.1700
#     META | Price = 149.03 | Action = 3.7632 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  92.30 | Action = 5.4972 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  28.50 | Action = 5.2535 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   5.12 | Action = 2.6890 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 50: Cash = 0.00, Portfolio = 10042.64
#     AAPL | Price =  54.45 | Action = 4.9258 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 130.16 | Action = 4.5676 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  52.46 | Action = 5.3117 | Trade = HOLD | Held = 4.1700
#     META | Price = 147.41 | Action = 2.8443 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  95.14 | Action = 5.3135 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  28.95 | Action = 3.1234 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   5.30 | Action = 3.5823 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 51: Cash = 0.00, Portfolio = 9519.49
#     AAPL | Price =  59.91 | Action = 4.1762 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 141.99 | Action = 5.5461 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  56.23 | Action = 4.3595 | Trade = HOLD | Held = 4.1700
#     META | Price = 160.22 | Action = 2.6343 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  97.00 | Action = 4.4775 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  33.67 | Action = 5.1632 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.21 | Action = 2.4489 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 52: Cash = 0.00, Portfolio = 9928.70
#     AAPL | Price =  59.58 | Action = 5.2425 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 140.63 | Action = 3.5753 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  54.82 | Action = 4.0303 | Trade = HOLD | Held = 4.1700
#     META | Price = 155.48 | Action = 3.1205 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  94.29 | Action = 2.9697 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  35.95 | Action = 3.0400 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.12 | Action = 3.5538 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 53: Cash = 0.00, Portfolio = 9831.11
#     AAPL | Price =  62.72 | Action = 4.3630 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 149.43 | Action = 4.8151 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  57.87 | Action = 2.5476 | Trade = HOLD | Held = 4.1700
#     META | Price = 162.57 | Action = 1.0709 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  97.77 | Action = 6.3346 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  35.21 | Action = 5.3382 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.41 | Action = 2.9543 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 54: Cash = 0.00, Portfolio = 10019.20
#     AAPL | Price =  60.12 | Action = 4.9502 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 143.29 | Action = 4.5970 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  55.25 | Action = 7.4077 | Trade = HOLD | Held = 4.1700
#     META | Price = 156.05 | Action = 3.9091 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  95.00 | Action = 3.3731 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  34.29 | Action = 4.4914 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.30 | Action = 1.2171 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 55: Cash = 0.00, Portfolio = 10365.14
#     AAPL | Price =  61.84 | Action = 4.1811 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 153.37 | Action = 4.9628 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  57.04 | Action = 4.0741 | Trade = HOLD | Held = 4.1700
#     META | Price = 165.17 | Action = 3.1609 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  98.20 | Action = 5.3251 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  33.48 | Action = 3.2801 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.62 | Action = 3.3425 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 56: Cash = 0.00, Portfolio = 10082.01
#     AAPL | Price =  61.71 | Action = 6.2709 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 150.96 | Action = 3.5824 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  57.82 | Action = 3.8501 | Trade = HOLD | Held = 4.1700
#     META | Price = 166.02 | Action = 2.5940 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  97.49 | Action = 4.2871 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  34.93 | Action = 2.8549 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.57 | Action = 4.1834 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 57: Cash = 0.00, Portfolio = 10421.70
#     AAPL | Price =  58.46 | Action = 3.9621 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 145.60 | Action = 6.5912 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  54.84 | Action = 4.4090 | Trade = HOLD | Held = 4.1700
#     META | Price = 158.85 | Action = 2.3758 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  95.39 | Action = 2.2488 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  32.10 | Action = 4.8751 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.05 | Action = 1.9289 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 58: Cash = 0.00, Portfolio = 10460.26
#     AAPL | Price =  59.44 | Action = 4.2168 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 148.61 | Action = 4.6173 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  55.59 | Action = 3.2182 | Trade = HOLD | Held = 4.1700
#     META | Price = 157.45 | Action = 2.2189 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  95.94 | Action = 6.1020 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  30.30 | Action = 3.4336 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.36 | Action = 4.1978 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 59: Cash = 0.00, Portfolio = 9767.55
#     AAPL | Price =  58.59 | Action = 5.3857 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 147.24 | Action = 4.9164 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  54.38 | Action = 3.3932 | Trade = HOLD | Held = 4.1700
#     META | Price = 153.46 | Action = 3.1610 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  95.33 | Action = 2.1933 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  32.00 | Action = 5.2753 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.08 | Action = 4.0951 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 60: Cash = 0.00, Portfolio = 10159.82
#     AAPL | Price =  63.70 | Action = 4.1212 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 158.19 | Action = 3.6617 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  58.88 | Action = 3.4672 | Trade = HOLD | Held = 4.1700
#     META | Price = 164.77 | Action = 2.2459 | Trade =  BUY | Held = 0.0000
#     AMZN | Price =  99.88 | Action = 4.4663 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  34.42 | Action = 5.0725 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.69 | Action = 4.7131 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 61: Cash = 0.00, Portfolio = 10242.49
#     AAPL | Price =  62.96 | Action = 4.2618 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 156.49 | Action = 5.5407 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  58.85 | Action = 3.3450 | Trade = HOLD | Held = 4.1700
#     META | Price = 168.04 | Action = 2.3901 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 100.58 | Action = 2.3017 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  36.36 | Action = 3.5440 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.45 | Action = 4.1382 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 62: Cash = 0.00, Portfolio = 10391.88
#     AAPL | Price =  64.57 | Action = 3.3809 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 158.06 | Action = 2.8445 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  60.06 | Action = 6.9056 | Trade = HOLD | Held = 4.1700
#     META | Price = 173.46 | Action = 2.7080 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 102.15 | Action = 3.2973 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  36.59 | Action = 2.9725 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.65 | Action = 4.5339 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 63: Cash = 0.00, Portfolio = 10464.81
#     AAPL | Price =  65.04 | Action = 5.4284 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 158.07 | Action = 2.3453 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  60.04 | Action = 2.7925 | Trade = HOLD | Held = 4.1700
#     META | Price = 174.37 | Action = 1.8240 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 102.14 | Action = 2.6548 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  38.20 | Action = 5.7710 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.55 | Action = 1.0737 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 64: Cash = 0.00, Portfolio = 10756.00
#     AAPL | Price =  66.31 | Action = 4.5543 | Trade = HOLD | Held = 26.1262
#     MSFT | Price = 158.42 | Action = 4.8838 | Trade = HOLD | Held = 0.2114
#    GOOGL | Price =  60.23 | Action = 3.1764 | Trade = HOLD | Held = 4.1700
#     META | Price = 173.97 | Action = 1.1718 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 108.44 | Action = 3.2275 | Trade = HOLD | Held = 23.9185
#     TSLA | Price =  43.40 | Action = 2.9518 | Trade = HOLD | Held = 70.1449
#     NVDA | Price =   6.72 | Action = 2.3246 | Trade = HOLD | Held = 228.9407
# ------------------------------------------------------------
# Day 65: Cash = 0.00, Portfolio = 10846.28
#     AAPL | Price =  69.66 | Action = 5.8634 | Trade = HOLD | Held = 32.7591
#     MSFT | Price = 166.26 | Action = 2.9193 | Trade = HOLD | Held = 1.6276
#    GOOGL | Price =  62.96 | Action = 4.9310 | Trade = HOLD | Held = 10.2919
#     META | Price = 177.33 | Action = 2.9740 | Trade =  BUY | Held = 1.2154
#     AMZN | Price = 114.17 | Action = 1.3414 | Trade = HOLD | Held = 24.8842
#     TSLA | Price =  47.33 | Action = 3.1873 | Trade = HOLD | Held = 75.2550
#     NVDA | Price =   7.07 | Action = -0.3244 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 66: Cash = 0.00, Portfolio = 10718.52
#     AAPL | Price =  69.03 | Action = 5.5921 | Trade = HOLD | Held = 32.7591
#     MSFT | Price = 164.52 | Action = 3.3708 | Trade = HOLD | Held = 1.6276
#    GOOGL | Price =  62.57 | Action = 4.6604 | Trade = HOLD | Held = 10.2919
#     META | Price = 176.14 | Action = 3.0838 | Trade = HOLD | Held = 1.2154
#     AMZN | Price = 115.38 | Action = 1.4349 | Trade = HOLD | Held = 24.8842
#     TSLA | Price =  48.66 | Action = 2.8701 | Trade = HOLD | Held = 75.2550
#     NVDA | Price =   7.00 | Action = 2.5198 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 67: Cash = 0.00, Portfolio = 10585.54
#     AAPL | Price =  69.57 | Action = 7.2240 | Trade = HOLD | Held = 32.7591
#     MSFT | Price = 169.46 | Action = 3.4066 | Trade = HOLD | Held = 1.6276
#    GOOGL | Price =  62.57 | Action = 5.2318 | Trade = HOLD | Held = 10.2919
#     META | Price = 175.42 | Action = 1.5169 | Trade = HOLD | Held = 1.2154
#     AMZN | Price = 120.41 | Action = 1.3899 | Trade = HOLD | Held = 24.8842
#     TSLA | Price =  49.68 | Action = 0.9305 | Trade = HOLD | Held = 75.2550
#     NVDA | Price =   7.34 | Action = 2.7174 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 68: Cash = 0.00, Portfolio = 10696.36
#     AAPL | Price =  68.63 | Action = 6.3118 | Trade = HOLD | Held = 32.7591
#     MSFT | Price = 170.95 | Action = 4.0204 | Trade = HOLD | Held = 1.6276
#    GOOGL | Price =  63.65 | Action = 3.9047 | Trade = HOLD | Held = 10.2919
#     META | Price = 178.40 | Action = 1.7864 | Trade = HOLD | Held = 1.2154
#     AMZN | Price = 118.75 | Action = 2.2072 | Trade = HOLD | Held = 24.8842
#     TSLA | Price =  50.26 | Action = 2.6859 | Trade = HOLD | Held = 75.2550
#     NVDA | Price =   7.28 | Action = 1.9373 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 69: Cash = 0.00, Portfolio = 10704.26
#     AAPL | Price =  67.21 | Action = 3.9653 | Trade = HOLD | Held = 32.7591
#     MSFT | Price = 167.56 | Action = 4.5920 | Trade = HOLD | Held = 1.6276
#    GOOGL | Price =  62.76 | Action = 2.9402 | Trade = HOLD | Held = 10.2919
#     META | Price = 177.40 | Action = 2.2456 | Trade = HOLD | Held = 1.2154
#     AMZN | Price = 119.68 | Action = 0.9690 | Trade = HOLD | Held = 24.8842
#     TSLA | Price =  49.76 | Action = 3.0781 | Trade = HOLD | Held = 75.2550
#     NVDA | Price =   7.15 | Action = 3.7940 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 70: Cash = 0.00, Portfolio = 10866.83
#     AAPL | Price =  65.13 | Action = 5.6591 | Trade = HOLD | Held = 32.7591
#     MSFT | Price = 160.63 | Action = 4.0730 | Trade = HOLD | Held = 1.6276
#    GOOGL | Price =  60.32 | Action = 2.9868 | Trade = HOLD | Held = 10.2919
#     META | Price = 170.00 | Action = 0.8335 | Trade = HOLD | Held = 1.2154
#     AMZN | Price = 116.41 | Action = 1.6608 | Trade = HOLD | Held = 24.8842
#     TSLA | Price =  45.78 | Action = 3.9690 | Trade = HOLD | Held = 75.2550
#     NVDA | Price =   6.71 | Action = 1.1730 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 71: Cash = 0.00, Portfolio = 10849.78
#     AAPL | Price =  67.00 | Action = 4.4495 | Trade = HOLD | Held = 33.4618
#     MSFT | Price = 166.09 | Action = 2.7953 | Trade = HOLD | Held = 1.8190
#    GOOGL | Price =  62.62 | Action = 4.1441 | Trade = HOLD | Held = 11.0211
#     META | Price = 181.42 | Action = -0.3555 | Trade = SELL | Held = 0.0000
#     AMZN | Price = 118.17 | Action = 2.3556 | Trade = HOLD | Held = 25.1156
#     TSLA | Price =  48.81 | Action = 3.8532 | Trade = HOLD | Held = 76.1158
#     NVDA | Price =   7.13 | Action = 4.2031 | Trade =  BUY | Held = 5.7656
# ------------------------------------------------------------
# Day 72: Cash = 0.00, Portfolio = 11023.16
#     AAPL | Price =  66.74 | Action = 5.7179 | Trade = HOLD | Held = 33.4618
#     MSFT | Price = 164.08 | Action = 2.3741 | Trade = HOLD | Held = 1.8190
#    GOOGL | Price =  63.26 | Action = 5.0863 | Trade = HOLD | Held = 11.0211
#     META | Price = 184.26 | Action = 0.3454 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 119.97 | Action = 2.1813 | Trade = HOLD | Held = 25.1156
#     TSLA | Price =  47.04 | Action = 3.9255 | Trade = HOLD | Held = 76.1158
#     NVDA | Price =   7.07 | Action = 3.5808 | Trade = HOLD | Held = 5.7656
# ------------------------------------------------------------
# Day 73: Cash = 0.00, Portfolio = 10994.25
#     AAPL | Price =  68.67 | Action = 3.5839 | Trade = HOLD | Held = 33.4618
#     MSFT | Price = 167.08 | Action = 2.7524 | Trade = HOLD | Held = 1.8190
#    GOOGL | Price =  63.53 | Action = 2.7477 | Trade = HOLD | Held = 11.0211
#     META | Price = 189.18 | Action = 1.8391 | Trade =  BUY | Held = 0.0000
#     AMZN | Price = 120.51 | Action = 2.0598 | Trade = HOLD | Held = 25.1156
#     TSLA | Price =  48.34 | Action = 3.5474 | Trade = HOLD | Held = 76.1158
#     NVDA | Price =   7.21 | Action = 2.4456 | Trade = HOLD | Held = 5.7656
# ------------------------------------------------------------
# Day 74: Cash = 0.00, Portfolio = 10949.22
#     AAPL | Price =  68.72 | Action = 7.0992 | Trade = HOLD | Held = 33.4618
#     MSFT | Price = 166.60 | Action = 2.8089 | Trade = HOLD | Held = 1.8190
#    GOOGL | Price =  63.24 | Action = 4.3174 | Trade = HOLD | Held = 11.0211
#     META | Price = 186.62 | Action = -0.9594 | Trade = HOLD | Held = 0.0000
#     AMZN | Price = 118.80 | Action = 3.4412 | Trade = HOLD | Held = 25.1156
#     TSLA | Price =  53.25 | Action = 4.6402 | Trade = HOLD | Held = 76.1158
#     NVDA | Price =   7.40 | Action = 5.2275 | Trade = HOLD | Held = 5.7656
# ------------------------------------------------------------
# Day 75: Cash = 0.00, Portfolio = 10922.17
#     AAPL | Price =  67.61 | Action = 5.1726 | Trade = HOLD | Held = 33.4618
# ...
# ------------------------------------------------------------
# Day 707: Cash = 0.00, Portfolio = 38060.65
#     AAPL | Price = 153.70 | Action = -3.6985 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 230.95 | Action = 0.3255 | Trade = HOLD | Held = 0.4011
#    GOOGL | Price =  95.83 | Action = 0.8854 | Trade =  BUY | Held = 0.0000
#     META | Price =  98.73 | Action = 4.9511 | Trade = HOLD | Held = 165.9662
#     AMZN | Price = 103.41 | Action = 2.7413 | Trade = HOLD | Held = 5.1265
#     TSLA | Price = 228.52 | Action = 4.0600 | Trade = HOLD | Held = 104.3463
#     NVDA | Price =  13.82 | Action = 0.1058 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 708: Cash = 0.00, Portfolio = 37632.98
#     AAPL | Price = 151.33 | Action = -2.0905 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 227.28 | Action = 1.5718 | Trade = HOLD | Held = 0.4011
#    GOOGL | Price =  94.06 | Action = 1.7110 | Trade =  BUY | Held = 0.0000
#     META | Price =  92.72 | Action = 4.8513 | Trade = HOLD | Held = 165.9662
#     AMZN | Price = 102.44 | Action = 2.8423 | Trade = HOLD | Held = 5.1265
#     TSLA | Price = 227.54 | Action = 4.9020 | Trade = HOLD | Held = 104.3463
#     NVDA | Price =  13.48 | Action = -2.1194 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 709: Cash = 0.00, Portfolio = 37518.81
#     AAPL | Price = 148.67 | Action = -3.4615 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 223.41 | Action = -0.7804 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  90.04 | Action = 1.2791 | Trade =  BUY | Held = 0.1010
#     META | Price =  94.75 | Action = 3.8661 | Trade = HOLD | Held = 166.2316
#     AMZN | Price =  96.79 | Action = 2.5756 | Trade = HOLD | Held = 5.3349
#     TSLA | Price = 227.82 | Action = 4.9321 | Trade = HOLD | Held = 104.5503
#     NVDA | Price =  13.53 | Action = -1.0332 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 710: Cash = 0.00, Portfolio = 40420.99
#     AAPL | Price = 143.13 | Action = -1.1557 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 215.51 | Action = 0.5189 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  86.56 | Action = 1.0821 | Trade = HOLD | Held = 0.1010
#     META | Price =  90.12 | Action = 5.5745 | Trade = HOLD | Held = 166.2316
#     AMZN | Price =  92.12 | Action = 1.9261 | Trade = HOLD | Held = 5.3349
#     TSLA | Price = 214.98 | Action = 3.5513 | Trade = HOLD | Held = 104.5503
#     NVDA | Price =  13.20 | Action = 0.1078 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 711: Cash = 0.00, Portfolio = 40802.60
#     AAPL | Price = 137.06 | Action = -1.0866 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 209.78 | Action = 1.5660 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  83.03 | Action = 1.3131 | Trade = HOLD | Held = 0.1010
#     META | Price =  88.49 | Action = 3.4809 | Trade = HOLD | Held = 166.2316
#     AMZN | Price =  89.30 | Action = 2.4244 | Trade = HOLD | Held = 5.3349
#     TSLA | Price = 215.31 | Action = 2.2759 | Trade = HOLD | Held = 104.5503
#     NVDA | Price =  13.41 | Action = -1.8137 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 712: Cash = 0.00, Portfolio = 41316.59
#     AAPL | Price = 136.79 | Action = -1.0708 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 216.77 | Action = -0.8459 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  86.17 | Action = 1.4674 | Trade = HOLD | Held = 0.1010
#     META | Price =  90.36 | Action = 5.8232 | Trade = HOLD | Held = 166.2316
#     AMZN | Price =  90.98 | Action = 5.0726 | Trade = HOLD | Held = 5.3349
#     TSLA | Price = 207.47 | Action = 1.4324 | Trade = HOLD | Held = 104.5503
#     NVDA | Price =  14.14 | Action = -2.5101 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 713: Cash = 0.00, Portfolio = 39827.00
#     AAPL | Price = 137.32 | Action = -1.5392 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 223.11 | Action = -1.8828 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  88.07 | Action = -0.7596 | Trade = SELL | Held = 0.0000
#     META | Price =  96.27 | Action = 3.5488 | Trade = HOLD | Held = 166.2598
#     AMZN | Price =  90.53 | Action = 1.9649 | Trade = HOLD | Held = 5.3558
#     TSLA | Price = 197.08 | Action = 4.3025 | Trade = HOLD | Held = 104.5731
#     NVDA | Price =  14.29 | Action = 0.5112 | Trade =  BUY | Held = 0.0298
# ------------------------------------------------------------
# Day 714: Cash = 0.00, Portfolio = 38162.04
#     AAPL | Price = 137.90 | Action = 0.4399 | Trade =  BUY | Held = 0.0002
#     MSFT | Price = 224.09 | Action = -1.4895 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  88.48 | Action = 0.8025 | Trade =  BUY | Held = 0.0004
#     META | Price =  96.02 | Action = 3.8803 | Trade = HOLD | Held = 166.2615
#     AMZN | Price =  89.98 | Action = 2.7390 | Trade = HOLD | Held = 5.3574
#     TSLA | Price = 191.30 | Action = 1.6777 | Trade = HOLD | Held = 104.5736
#     NVDA | Price =  14.59 | Action = -1.5440 | Trade = SELL | Held = 0.0000
# ------------------------------------------------------------
# Day 715: Cash = 0.00, Portfolio = 37527.28
#     AAPL | Price = 133.32 | Action = -0.7546 | Trade = SELL | Held = 0.0000
#     MSFT | Price = 219.82 | Action = 0.3144 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  86.90 | Action = -1.1310 | Trade = SELL | Held = 0.0000
#     META | Price = 100.99 | Action = 3.9295 | Trade = HOLD | Held = 166.2618
#     AMZN | Price =  86.14 | Action = 1.6496 | Trade = HOLD | Held = 5.3575
#     TSLA | Price = 177.59 | Action = 1.2023 | Trade = HOLD | Held = 104.5737
#     NVDA | Price =  13.76 | Action = -1.0501 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 716: Cash = 0.00, Portfolio = 37706.34
#     AAPL | Price = 145.18 | Action = 1.1676 | Trade =  BUY | Held = 0.0000
#     MSFT | Price = 237.91 | Action = -1.2908 | Trade = SELL | Held = 0.0000
#    GOOGL | Price =  93.49 | Action = 1.7278 | Trade =  BUY | Held = 0.0000
#     META | Price = 111.35 | Action = 4.2024 | Trade = HOLD | Held = 166.2618
#     AMZN | Price =  96.63 | Action = 1.0515 | Trade = HOLD | Held = 5.3575
#     TSLA | Price = 190.72 | Action = 1.8302 | Trade = HOLD | Held = 104.5737
#     NVDA | Price =  15.73 | Action = -1.4410 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 717: Cash = 0.00, Portfolio = 38380.57
#     AAPL | Price = 147.98 | Action = 0.3937 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 241.95 | Action = -1.6963 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  95.95 | Action = 2.1013 | Trade = HOLD | Held = 0.0000
#     META | Price = 112.49 | Action = 3.3703 | Trade = HOLD | Held = 166.2618
#     AMZN | Price = 100.79 | Action = 2.4081 | Trade = HOLD | Held = 5.3575
#     TSLA | Price = 195.97 | Action = 2.8515 | Trade = HOLD | Held = 104.5737
#     NVDA | Price =  16.31 | Action = -1.2506 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 718: Cash = 0.00, Portfolio = 37017.11
#     AAPL | Price = 146.58 | Action = 1.8501 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 236.51 | Action = -1.0400 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  95.24 | Action = -0.0368 | Trade = SELL | Held = 0.0000
#     META | Price = 113.68 | Action = 4.2749 | Trade = HOLD | Held = 166.2618
#     AMZN | Price =  98.49 | Action = 4.9129 | Trade = HOLD | Held = 5.3575
#     TSLA | Price = 190.95 | Action = 1.4897 | Trade = HOLD | Held = 104.5737
#     NVDA | Price =  16.28 | Action = -2.3357 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 719: Cash = 0.00, Portfolio = 37209.30
#     AAPL | Price = 148.32 | Action = 0.8644 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 236.92 | Action = -0.3962 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  97.97 | Action = 1.8897 | Trade =  BUY | Held = 0.0000
#     META | Price = 116.53 | Action = 3.6873 | Trade = HOLD | Held = 166.2618
#     AMZN | Price =  98.94 | Action = 2.2514 | Trade = HOLD | Held = 5.3575
#     TSLA | Price = 194.42 | Action = 1.9988 | Trade = HOLD | Held = 104.5737
#     NVDA | Price =  16.65 | Action = -1.3249 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 720: Cash = 0.00, Portfolio = 37008.74
#     AAPL | Price = 147.08 | Action = 1.1065 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 237.35 | Action = -0.7776 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  98.38 | Action = 1.3531 | Trade =  BUY | Held = 0.0000
#     META | Price = 112.70 | Action = 3.6808 | Trade = HOLD | Held = 166.2618
#     AMZN | Price =  97.12 | Action = 3.7418 | Trade = HOLD | Held = 5.3575
#     TSLA | Price = 186.92 | Action = 2.1501 | Trade = HOLD | Held = 104.5737
#     NVDA | Price =  15.89 | Action = 0.4222 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 721: Cash = 0.00, Portfolio = 36182.73
#     AAPL | Price = 148.99 | Action = 4.2588 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 237.30 | Action = -1.2785 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  97.89 | Action = 1.3111 | Trade =  BUY | Held = 0.0000
#     META | Price = 110.93 | Action = 3.4880 | Trade = HOLD | Held = 166.2618
#     AMZN | Price =  94.85 | Action = 2.1800 | Trade = HOLD | Held = 5.3575
#     TSLA | Price = 183.17 | Action = 1.9706 | Trade = HOLD | Held = 104.5737
#     NVDA | Price =  15.66 | Action = -2.1302 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 722: Cash = 0.00, Portfolio = 35944.32
#     AAPL | Price = 149.55 | Action = 5.6194 | Trade = HOLD | Held = 0.0000
#     MSFT | Price = 236.85 | Action = -3.3320 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  96.97 | Action = 0.1814 | Trade =  BUY | Held = 0.0000
#     META | Price = 111.52 | Action = 5.7830 | Trade = HOLD | Held = 166.2618
#     AMZN | Price =  94.14 | Action = 0.4497 | Trade = HOLD | Held = 5.3575
#     TSLA | Price = 180.19 | Action = 2.4123 | Trade = HOLD | Held = 104.5737
#     NVDA | Price =  15.39 | Action = -1.1521 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 723: Cash = 0.00, Portfolio = 35071.79
#     AAPL | Price = 146.31 | Action = 4.2222 | Trade = HOLD | Held = 54.9801
#     MSFT | Price = 237.67 | Action = -0.8836 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  95.15 | Action = 1.2098 | Trade =  BUY | Held = 23.4202
#     META | Price = 109.34 | Action = 2.0345 | Trade = HOLD | Held = 196.6852
#     AMZN | Price =  92.46 | Action = 1.7316 | Trade = HOLD | Held = 40.1011
#     TSLA | Price = 167.87 | Action = -1.0128 | Trade = SELL | Held = 0.0000
#     NVDA | Price =  15.30 | Action = -2.5776 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 724: Cash = 0.00, Portfolio = 35603.27
#     AAPL | Price = 148.45 | Action = 3.1664 | Trade = HOLD | Held = 54.9801
#     MSFT | Price = 240.59 | Action = 1.8592 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  96.59 | Action = 1.3161 | Trade = HOLD | Held = 23.4202
#     META | Price = 110.92 | Action = 3.4863 | Trade = HOLD | Held = 196.6852
#     AMZN | Price =  93.20 | Action = 2.9937 | Trade = HOLD | Held = 40.1011
#     TSLA | Price = 169.91 | Action = 2.5635 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  16.02 | Action = -1.9494 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 725: Cash = 0.00, Portfolio = 36373.57
#     AAPL | Price = 149.33 | Action = 3.7594 | Trade = HOLD | Held = 54.9801
#     MSFT | Price = 243.10 | Action = 0.4733 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  97.99 | Action = 2.4864 | Trade = HOLD | Held = 23.4202
#     META | Price = 111.71 | Action = 4.3666 | Trade = HOLD | Held = 196.6852
#     AMZN | Price =  94.13 | Action = 3.3668 | Trade = HOLD | Held = 40.1011
#     TSLA | Price = 183.20 | Action = 5.0244 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  16.50 | Action = -2.2289 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 726: Cash = 0.00, Portfolio = 35519.83
#     AAPL | Price = 146.41 | Action = 3.3062 | Trade = HOLD | Held = 54.9801
#     MSFT | Price = 243.01 | Action = -0.9810 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  97.00 | Action = 1.8372 | Trade = HOLD | Held = 23.4202
#     META | Price = 110.89 | Action = 0.9013 | Trade = HOLD | Held = 196.6852
#     AMZN | Price =  93.41 | Action = 1.7641 | Trade = HOLD | Held = 40.1011
#     TSLA | Price = 182.86 | Action = 2.8554 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  16.25 | Action = -2.2968 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 727: Cash = 0.00, Portfolio = 35772.63
#     AAPL | Price = 142.56 | Action = 4.2444 | Trade = HOLD | Held = 54.9801
#     MSFT | Price = 237.38 | Action = -0.9598 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price =  95.59 | Action = 3.5296 | Trade = HOLD | Held = 23.4202
#     META | Price = 108.27 | Action = 2.1629 | Trade = HOLD | Held = 196.6852
#     AMZN | Price =  93.95 | Action = 4.1918 | Trade = HOLD | Held = 40.1011
#     TSLA | Price = 182.92 | Action = 4.2797 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  15.81 | Action = 1.1142 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 728: Cash = 0.00, Portfolio = 35314.58
#     AAPL | Price = 139.55 | Action = 4.6011 | Trade = HOLD | Held = 54.9801
#     MSFT | Price = 235.98 | Action = 3.2657 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  94.74 | Action = 2.3719 | Trade = HOLD | Held = 23.4202
#     META | Price = 108.95 | Action = 3.9880 | Trade = HOLD | Held = 196.6852
#     AMZN | Price =  92.42 | Action = 5.3126 | Trade = HOLD | Held = 40.1011
#     TSLA | Price = 180.83 | Action = 5.4845 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  15.62 | Action = -0.7102 | Trade = HOLD | Held = 0.0000
# ------------------------------------------------------------
# Day 729: Cash = 0.00, Portfolio = 34770.21
#     AAPL | Price = 146.33 | Action = 4.2239 | Trade = HOLD | Held = 54.9801
#     MSFT | Price = 250.52 | Action = -0.8998 | Trade = HOLD | Held = 0.0000
#    GOOGL | Price = 100.51 | Action = 4.5347 | Trade = HOLD | Held = 23.4202
#     META | Price = 117.55 | Action = 4.4441 | Trade = HOLD | Held = 196.6852
#     AMZN | Price =  96.54 | Action = 3.0764 | Trade = HOLD | Held = 40.1011
#     TSLA | Price = 194.70 | Action = 5.5888 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  16.91 | Action = 1.6858 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 730: Cash = 0.00, Portfolio = 36023.85
#     AAPL | Price = 146.61 | Action = 7.0823 | Trade = HOLD | Held = 54.9801
#     MSFT | Price = 250.08 | Action = 1.8895 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price = 100.51 | Action = 5.1922 | Trade = HOLD | Held = 23.4202
#     META | Price = 119.88 | Action = 2.2395 | Trade = HOLD | Held = 196.6852
#     AMZN | Price =  95.50 | Action = 4.8671 | Trade = HOLD | Held = 40.1011
#     TSLA | Price = 194.70 | Action = 4.1156 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  17.12 | Action = 0.1011 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
# Day 731: Cash = 0.00, Portfolio = 36044.56
#     AAPL | Price = 146.11 | Action = 4.0259 | Trade = HOLD | Held = 54.9801
#     MSFT | Price = 250.40 | Action = 1.0345 | Trade =  BUY | Held = 0.0000
#    GOOGL | Price =  99.96 | Action = 1.7397 | Trade = HOLD | Held = 23.4202
#     META | Price = 122.91 | Action = 2.7603 | Trade = HOLD | Held = 196.6852
#     AMZN | Price =  94.13 | Action = 1.9164 | Trade = HOLD | Held = 40.1011
#     TSLA | Price = 194.86 | Action = 5.2067 | Trade =  BUY | Held = 0.0000
#     NVDA | Price =  16.86 | Action = 2.0414 | Trade =  BUY | Held = 0.0000
# ------------------------------------------------------------
#
# Done. Final portfolio value: 36044.56

# %%
bh_env = BuyAndHoldEnvironment(raw_prices)
bh_env.run(start_index=state_dim)

# 1) Plot PPO vs Buy & Hold
plt.figure(figsize=(12, 6))
plt.plot(env.portfolio_values, label='PPO Agent')
plt.plot(bh_env.portfolio_values, 'r--', label='Buy & Hold')
plt.title('Portfolio Value vs Buy & Hold')
plt.xlabel('Days')
plt.ylabel('Portfolio Value')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.savefig("Training_PF_overtime4.png")
plt.show()

# 3) Final values
print("\nFinal Results:")
print(f"PPO final portfolio:       {env.portfolio_values[-1]:.2f}")
print(f"Buy & Hold final portfolio:{bh_env.portfolio_values[-1]:.2f}")


# 1) Convert dates to datetime explicitly
dates = pd.to_datetime(data[tickers[0]]["dates"])  # ensure it's datetime

# 2) Align the PPO curve to start after `state_dim`
ppo_curve = env.portfolio_values
L_ppo = len(ppo_curve)
ppo_dates = dates[state_dim - 1 : state_dim - 1 + L_ppo]

# 3) Buy & Hold
bh = BuyAndHoldEnvironment(raw_prices)
bh.run(start_index=state_dim)
bh_curve = bh.portfolio_values
L_bh = len(bh_curve)
bh_dates = dates[state_dim - 1 : state_dim - 1 + L_bh]

# 4) Truncate both to the shortest length
min_len = min(len(ppo_dates), len(bh_dates), len(ppo_curve), len(bh_curve))

ppo_dates = ppo_dates[:min_len]
ppo_curve = ppo_curve[:min_len]
bh_dates  = bh_dates[:min_len]
bh_curve  = bh_curve[:min_len]

# 5) Plot
fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(ppo_dates, ppo_curve, label="PPO Agent")
ax.plot(bh_dates, bh_curve, 'r--', label="Buy & Hold")

ax.set_title("Portfolio Value vs Buy & Hold")
ax.set_ylabel("Portfolio Value")
ax.legend()
ax.grid(True)

# Format x-axis
ax.xaxis.set_major_locator(mdates.MonthLocator(interval=2))
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
fig.autofmt_xdate()

plt.tight_layout()
plt.savefig("MLP_CP_DATES_6.png", dpi=600)
plt.show()
# Out:
# Final Results:
# PPO final portfolio:       36044.56
# Buy & Hold final portfolio:17379.21

# %%
# === 1. Initialize environment and reset ===
env = MultiStockEnvironment(data, window_size=state_dim)
state = env.reset()

alloc_history = []
price_history = []

# === 2. Run simulation and record actions/allocations ===
day = 0
while not env.done:
    actions = {}
    prices_today = []
    allocs_today = []

    for t in tickers:
        win = state[t]
        st = torch.tensor(win, dtype=torch.float32).view(1, -1)
        a_tensor, _ = get_action(st, w1, w2a, log_std)
        a_val = a_tensor.item()
        actions[t] = a_val
        prices_today.append(env.data[t]["raw"][env.t + env.window_size])
        allocs_today.append(max(a_val, 0.0))

    alloc_sum = sum(allocs_today)
    if alloc_sum > 0:
        allocs_today = [a / alloc_sum for a in allocs_today]
    else:
        allocs_today = [0.0] * len(tickers)

    alloc_history.append(allocs_today)
    price_history.append(prices_today)

    state, _, _, _ = env.step(actions)
    day += 1

# Normalize allocation data to [-1, 1] for consistent colormap
alloc_norm = np.array(alloc_array)
alloc_norm = 2 * (alloc_norm - alloc_norm.min()) / (alloc_norm.max() - alloc_norm.min()) - 1

# Normalize prices using z-score (already centered around 0)
norm_prices = (price_array - price_array.mean(axis=1, keepdims=True)) / price_array.std(axis=1, keepdims=True)

# === 4. Plot both heatmaps using the same colormap ===
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

# Shared limits for visual consistency
vmin, vmax = -1, 1

# Allocation heatmap
sns.heatmap(alloc_norm, cmap="coolwarm", center=0, vmin=vmin, vmax=vmax,
            cbar_kws={'label': 'Normalized Allocation'}, xticklabels=100, yticklabels=tickers, ax=ax1)
ax1.set_title("Portfolio Allocation Heatmap")
ax1.set_ylabel("Asset")

# Price heatmap
sns.heatmap(norm_prices, cmap="coolwarm", center=0, vmin=vmin, vmax=vmax,
            cbar_kws={'label': 'Price Z-Score'}, xticklabels=100, yticklabels=tickers, ax=ax2)
ax2.set_title("Price Movement Heatmap")
ax2.set_ylabel("Asset")
ax2.set_xlabel("Time Step")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Run the Environment 50 times to get an average on how the MLP is performing

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pickle
import torch.nn.functional as F
import os

# === Setup ===
tickers = ["AAPL", "MSFT", "GOOGL", "META", "AMZN", "TSLA", "NVDA"]
state_dim = 5
feat_dim = 6
action_dim = 1
n_runs = 20

w1 = torch.nn.Parameter(torch.empty(state_dim * feat_dim, 64))
w2a = torch.nn.Parameter(torch.empty(64, action_dim))
log_std = torch.nn.Parameter(torch.empty(action_dim))


state_dict = torch.load("MLP_Features/MLP_feature_v2.pth")
w1.data.copy_(state_dict['w1'])
w2a.data.copy_(state_dict['w2a'])
log_std.data.copy_(state_dict['log_std'])

# === Load Buy & Hold data ===
with open("buyhold_2020_2023.pkl", "rb") as f:
    bh_data = pickle.load(f)
buy_hold_curve = bh_data["curve"]
buy_hold_value = buy_hold_curve[-1]
bh_dates = pd.to_datetime(bh_data["dates"])

# === Run PPO agent ===
final_portfolios = []
ppo_trajectories = []

for run in range(n_runs):
    env = MultiStockEnvironment(data, window_size=state_dim)
    state_dict = env.reset()
    done = False

    while not done:
        actions = {}
        for t in tickers:
            win = state_dict[t]              # shape: (5, 6)
            flat_win = win.flatten()         # shape: (30,)
            st = torch.tensor(flat_win, dtype=torch.float32).view(1, -1)
            with torch.no_grad():
                a_tensor, _ = get_action(st, w1, w2a, log_std)
            actions[t] = a_tensor.item()

        state_dict, _, done, _ = env.step(actions)

    final_value = env.portfolio_values[-1]
    final_portfolios.append(final_value)
    ppo_trajectories.append(env.portfolio_values)
    print(f"Run {run+1:2d}/{n_runs} → Final Portfolio Value: {final_value:.2f}")

"""
os.makedirs("MLP_Features", exist_ok=True)
pd.DataFrame(final_portfolios, columns=["final_portfolio_value"]).to_csv("MLP_Features/MLP_UNSEEN_TRAIN_ppo_final_portfolios.csv", index=False)

max_len = max(len(p) for p in ppo_trajectories)
for i in range(n_runs):
    last_val = ppo_trajectories[i][-1]
    ppo_trajectories[i] += [last_val] * (max_len - len(ppo_trajectories[i]))

#pd.DataFrame(ppo_trajectories).T.to_csv("MLP_Features/MLP_UNSEEN_TRAIN_ppo_all_trajectories.csv", index=False)
"""

# === Summary ===
mean_pf = np.mean(final_portfolios)
std_pf = np.std(final_portfolios)
min_pf = np.min(final_portfolios)
max_pf = np.max(final_portfolios)
beats_bh = sum(p > buy_hold_value for p in final_portfolios)
beat_pct = beats_bh / n_runs * 100

print(f"\nSummary over {n_runs} runs:")
print(f"→ Mean Final Portfolio: {mean_pf:.2f} ± {std_pf:.2f}")
print(f"→ Min: {min_pf:.2f}, Max: {max_pf:.2f}")
print(f"→ Buy & Hold Final Portfolio: {buy_hold_value:.2f}")
print(f"→ PPO Agent beat Buy & Hold in {beat_pct:.1f}% of runs ({beats_bh}/{n_runs})")

# === Histogram ===
plt.figure(figsize=(8, 4))
plt.hist(final_portfolios, bins=10, edgecolor='k', alpha=0.7)
plt.axvline(buy_hold_value, color='r', linestyle='--', linewidth=2,
            label=f'Buy & Hold = {buy_hold_value:.2f}')
plt.title("Distribution of Final Portfolio Values (PPO Agent – MLP + Features)")
plt.xlabel("Final Portfolio Value")
plt.ylabel("Count")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# === Trajectory plot ===
ppo_array = np.array(ppo_trajectories)
median_curve = np.median(ppo_array, axis=0)
std_curve = np.std(ppo_array, axis=0)

x_dates = bh_dates[state_dim - 1:state_dim - 1 + len(median_curve)]
min_len = min(len(x_dates), len(median_curve), len(buy_hold_curve))
x_dates = x_dates[:min_len]
median_curve = median_curve[:min_len]
std_curve = std_curve[:min_len]
buy_hold_curve = buy_hold_curve[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(x_dates, median_curve, label='PPO Median', linewidth=2)
plt.fill_between(x_dates, median_curve - std_curve, median_curve + std_curve,
                 color='skyblue', alpha=0.4, label='Std Dev')
plt.plot(x_dates, buy_hold_curve, 'r--', label='Buy & Hold')

plt.title("MLP (Features): Median Portfolio Value with Standard Deviation on Test Data")
plt.ylabel("Portfolio Value ($)")
plt.xlabel("Date")
plt.legend()
plt.grid(True)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=2))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.savefig("Training_PF_overtime_std_1.png")
plt.show()
# Out:
# /var/folders/1b/2dv3_3nx66s3980gg6hg5g1m0000gn/T/ipykernel_1984/3653464526.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load("MLP_Features/MLP_feature_GOOD.pth")
# Run  1/20 → Final Portfolio Value: 25659.95
# Run  2/20 → Final Portfolio Value: 21605.40
# Run  3/20 → Final Portfolio Value: 22080.96
# Run  4/20 → Final Portfolio Value: 16938.51
# Run  5/20 → Final Portfolio Value: 18886.79
# Run  6/20 → Final Portfolio Value: 23562.93
# Run  7/20 → Final Portfolio Value: 28280.10
# Run  8/20 → Final Portfolio Value: 22298.53
# Run  9/20 → Final Portfolio Value: 28302.02
# Run 10/20 → Final Portfolio Value: 21087.29
# Run 11/20 → Final Portfolio Value: 29632.46
# Run 12/20 → Final Portfolio Value: 20163.85
# Run 13/20 → Final Portfolio Value: 22703.17
# Run 14/20 → Final Portfolio Value: 18186.65
# Run 15/20 → Final Portfolio Value: 20889.25
# Run 16/20 → Final Portfolio Value: 18807.88
# Run 17/20 → Final Portfolio Value: 25047.09
# Run 18/20 → Final Portfolio Value: 25612.36
# Run 19/20 → Final Portfolio Value: 26999.39
# Run 20/20 → Final Portfolio Value: 23953.61
#
# Summary over 20 runs:
# → Mean Final Portfolio: 23034.91 ± 3529.85
# → Min: 16938.51, Max: 29632.46
# → Buy & Hold Final Portfolio: 17379.21
# → PPO Agent beat Buy & Hold in 95.0% of runs (19/20)

# %% [markdown]
# ### test on unseen data

# %%
tickers = ["AAPL", "MSFT", "GOOGL", "META", "AMZN", "TSLA", "NVDA"]
start, end = "2023-01-01", "2024-01-01"
initial_cash = 10000.0
state_dim = 5
n_runs = 20

# === Load test data with full features ===
data_test = {}
for t in tickers:
    df = yf.download(t, start=start, end=end)
    closes = df["Close"].astype(np.float32)
    mu, sigma = closes.mean(), closes.std()
    norm = (closes - mu) / sigma

    ema = closes.ewm(span=5, adjust=False).mean().astype(np.float32)
    delta = closes.diff()
    gain = delta.clip(lower=0).rolling(14).mean()
    loss = -delta.clip(upper=0).rolling(14).mean()
    rs = gain / loss
    rsi = (100 - 100 / (1 + rs)).astype(np.float32)
    ema12 = closes.ewm(span=12, adjust=False).mean()
    ema26 = closes.ewm(span=26, adjust=False).mean()
    macd = (ema12 - ema26).astype(np.float32)
    mbb = closes.rolling(20).mean()
    mbb_sd = closes.rolling(20).std()
    bb_upper = (mbb + 2 * mbb_sd).astype(np.float32)
    bb_lower = (mbb - 2 * mbb_sd).astype(np.float32)

    data_test[t] = {
        "dates": df.index,
        "raw": closes.values,
        "norm": norm.values,
        "ema": ema.values,
        "rsi": rsi.values,
        "macd": macd.values,
        "bb_upper": bb_upper.values,
        "bb_lower": bb_lower.values,
    }

# Drop NaNs
for t in tickers:
    feat_stack = np.column_stack([
        data_test[t]["norm"],
        data_test[t]["ema"],
        data_test[t]["rsi"],
        data_test[t]["macd"],
        data_test[t]["bb_upper"],
        data_test[t]["bb_lower"],
    ])
    valid_rows = ~np.isnan(feat_stack).any(axis=1)
    start_idx = np.argmax(valid_rows)

    for key in data_test[t]:
        data_test[t][key] = data_test[t][key][start_idx:]

# Normalize extra features
for t in tickers:
    for feat in ["ema", "rsi", "macd", "bb_upper", "bb_lower"]:
        arr = data_test[t][feat]
        mu, sigma = arr.mean(), arr.std()
        data_test[t][feat] = (arr - mu) / sigma

# Plot price preview
dates = data_test[tickers[0]]["dates"]
raw_prices_test = {t: data_test[t]["raw"] for t in tickers}
plt.figure(figsize=(12, 6))
for t in tickers:
    plt.plot(dates, raw_prices_test[t], label=t)
plt.title(f"Closing Prices: {', '.join(tickers)}\n{start} to {end}")
plt.xlabel("Date")
plt.ylabel("Closing Price (USD)")
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

bh_test = BuyAndHoldEnvironment(raw_prices_test)
bh_test.run(start_index=state_dim)
bh_final = bh_test.portfolio_values[-1]

# === PPO Evaluation ===
final_pf = []
ppo_trajectories = []

for run in range(n_runs):
    env_test = MultiStockEnvironment(data_test, window_size=state_dim)
    state_dict = env_test.reset()
    done = False

    while not done:
        actions = {}
        for t in tickers:
            win = state_dict[t]
            st = torch.tensor(win, dtype=torch.float32).view(1, -1)
            actions[t] = get_action(st, w1, w2a, log_std)[0].item()

        state_dict, port_val, done, _ = env_test.step(actions)

    final_pf.append(env_test.portfolio_values[-1])
    ppo_trajectories.append(env_test.portfolio_values)

# === Pad PPO trajectories and align Buy & Hold ===
max_len = max(len(p) for p in ppo_trajectories)
for i in range(n_runs):
    last = ppo_trajectories[i][-1]
    ppo_trajectories[i] += [last] * (max_len - len(ppo_trajectories[i]))

ppo_array = np.array(ppo_trajectories)
mean_curve = ppo_array.mean(axis=0)
std_pf = np.std(final_pf)
mean_pf = np.mean(final_pf)

bh_return = (bh_final / initial_cash - 1) * 100
print(f"Buy & Hold return: {bh_return:.2f}%")

buy_hold_curve = buy_hold_curve_full[:max_len]
bh_final = buy_hold_curve[-1]

# === Summary ===
print(f"\n=== PPO on Unseen Data (Test Set) ===")
print(f"Runs: {n_runs}")
print(f"Final portfolio  → mean {mean_pf:.2f} ±{std_pf:.2f}, min {np.min(final_pf):.2f}, max {np.max(final_pf):.2f}")
print(f"Buy&Hold baseline → {bh_final:.2f}")
beats = sum(p > bh_final for p in final_pf)
print(f"PPO beats Buy&Hold in {beats}/{n_runs} runs ({beats/n_runs*100:.1f}%)")

# === Annualized return ===
def annualized_return(final, initial, years):
    return ((final / initial) ** (1 / years) - 1) * 100

n_years = 1
print(f"Agent average annual return: {annualized_return(mean_pf, initial_cash, n_years):.2f}%")
print(f"Buy & Hold annual return:    {annualized_return(bh_final, initial_cash, n_years):.2f}%")

# === Histogram of final values ===
plt.figure(figsize=(6, 4))
plt.hist(final_pf, bins=10, edgecolor='k', alpha=0.7)
plt.axvline(bh_final, color='r', linestyle='--', linewidth=2,
            label=f'Buy&Hold')
plt.title("Distribution of Final Portfolio Values (Test)")
plt.xlabel("Final Portfolio Value")
plt.ylabel("Count")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# === Mean Portfolio Value Over Time with Std Dev (Fixed ±std) ===
std_curve = ppo_array.std(axis=0)

test_dates = data_test[tickers[0]]["dates"]
plot_dates = test_dates[state_dim - 1 : state_dim - 1 + max_len]

plt.figure(figsize=(10, 5))
plt.plot(plot_dates, mean_curve, label="PPO Mean", linewidth=2)
plt.fill_between(plot_dates,
                 mean_curve - std_curve,
                 mean_curve + std_curve,
                 color='skyblue', alpha=0.4, label='Std Dev')

plt.plot(plot_dates[:len(buy_hold_curve)],
         buy_hold_curve, 'r--', label=f'Buy & Hold = {bh_final:.2f}')
plt.title("MLP with Features: Test Set Portfolio Evaluation")
plt.xlabel("Date")
plt.ylabel("Portfolio Value")
#plt.savefig("MLP_Features/UNSEEN_PF_overtime.png")
plt.legend()
plt.grid(True)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=2))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

"""
df_final = pd.DataFrame({"final_portfolio_value": final_pf})
df_final.to_csv("MLP_Features/ppo_final_portfolios_test.csv", index=False)
print("\nSaved final portfolio values to 'MLP_Features/ppo_final_portfolios_test.csv'.")

df_traj = pd.DataFrame(ppo_trajectories).T
df_traj.to_csv("MLP_Features/ppo_all_trajectories_test.csv", index=False)
"""

# %%
import yfinance as yf
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import os
import pickle

tickers = ["AAPL", "MSFT", "GOOGL", "META", "AMZN", "TSLA", "NVDA"]
start, end = "2023-01-01", "2024-01-01"
initial_cash = 10000.0
state_dim = 5
n_runs = 5

# === Load model ===
state_dict = torch.load("MLP_feature_v2.pth")
w1 = torch.nn.Parameter(torch.empty(state_dim * 6, 64))
w2a = torch.nn.Parameter(torch.empty(64, 1))
log_std = torch.nn.Parameter(torch.empty(1))
w1.data.copy_(state_dict["w1"])
w2a.data.copy_(state_dict["w2a"])
log_std.data.copy_(state_dict["log_std"])

# === Load test Buy & Hold curve ===
with open("buyhold_test.pkl", "rb") as f:
    bh_data = pickle.load(f)
buy_hold_curve = bh_data["curve"]
bh_final = buy_hold_curve[-1]
bh_dates = pd.to_datetime(bh_data["dates"])

# === Prepare test data with full features ===
data_test = {}
for t in tickers:
    df = yf.download(t, start=start, end=end)
    closes = df["Close"].astype(np.float32)
    mu, sigma = closes.mean(), closes.std()
    norm = (closes - mu) / sigma

    ema = closes.ewm(span=5).mean().astype(np.float32)
    delta = closes.diff()
    gain = delta.clip(lower=0).rolling(14).mean()
    loss = -delta.clip(upper=0).rolling(14).mean()
    rs = gain / loss
    rsi = (100 - 100 / (1 + rs)).astype(np.float32)
    ema12 = closes.ewm(span=12).mean()
    ema26 = closes.ewm(span=26).mean()
    macd = (ema12 - ema26).astype(np.float32)
    mbb = closes.rolling(20).mean()
    mbb_sd = closes.rolling(20).std()
    bb_upper = (mbb + 2 * mbb_sd).astype(np.float32)
    bb_lower = (mbb - 2 * mbb_sd).astype(np.float32)

    data_test[t] = {
        "dates": df.index,
        "raw": closes.values,
        "norm": norm.values,
        "ema": ema.values,
        "rsi": rsi.values,
        "macd": macd.values,
        "bb_upper": bb_upper.values,
        "bb_lower": bb_lower.values,
    }

# Drop NaNs
for t in tickers:
    feat_stack = np.column_stack([
        data_test[t]["norm"],
        data_test[t]["ema"],
        data_test[t]["rsi"],
        data_test[t]["macd"],
        data_test[t]["bb_upper"],
        data_test[t]["bb_lower"],
    ])
    valid_rows = ~np.isnan(feat_stack).any(axis=1)
    start_idx = np.argmax(valid_rows)
    for key in data_test[t]:
        data_test[t][key] = data_test[t][key][start_idx:]

# Normalize features
for t in tickers:
    for feat in ["ema", "rsi", "macd", "bb_upper", "bb_lower"]:
        arr = data_test[t][feat]
        mu, sigma = arr.mean(), arr.std()
        data_test[t][feat] = (arr - mu) / sigma

# === PPO Evaluation ===
final_pf = []
ppo_trajectories = []

print("Running PPO (MLP + Features) on Test Data...\n")

for run in range(n_runs):
    env = MultiStockEnvironment(data_test, window_size=state_dim)
    state_dict = env.reset()
    done = False
    trajectory = [env.initial_cash]

    while not done:
        actions = {}
        for t in tickers:
            win = state_dict[t]
            flat = win.flatten()
            st = torch.tensor(flat, dtype=torch.float32).view(1, -1)
            a = get_action(st, w1, w2a, log_std)[0].item()
            actions[t] = a

        state_dict, pv, done, _ = env.step(actions)
        trajectory.append(pv)

    final_val = trajectory[-1]
    final_pf.append(final_val)
    ppo_trajectories.append(trajectory)
    print(f"Run {run+1:3d}/{n_runs} → Final Value: {final_val:.2f}")

# === Pad PPO trajectories and align Buy & Hold ===
max_len = max(len(p) for p in ppo_trajectories)
for i in range(n_runs):
    last = ppo_trajectories[i][-1]
    ppo_trajectories[i] += [last] * (max_len - len(ppo_trajectories[i]))

ppo_array = np.array(ppo_trajectories)
mean_curve = np.mean(ppo_array, axis=0)
std_curve  = np.std(ppo_array, axis=0)

# === Summary ===
mean_pf = np.mean(final_pf)
std_pf = np.std(final_pf)
beats = sum(p > bh_final for p in final_pf)
bh_return = (bh_final / initial_cash - 1) * 100

print(f"\n=== PPO on Unseen Data (MLP + Features) ===")
print(f"Runs: {n_runs}")
print(f"→ Final Portfolio: mean {mean_pf:.2f} ±{std_pf:.2f}")
print(f"→ Min: {np.min(final_pf):.2f}, Max: {np.max(final_pf):.2f}")
print(f"→ Buy & Hold Final Portfolio: {bh_final:.2f}")
print(f"→ PPO beats Buy & Hold in {beats}/{n_runs} runs ({beats/n_runs*100:.1f}%)")

def annualized_return(final, initial, years=1):
    return ((final / initial) ** (1 / years) - 1) * 100

print(f"→ PPO Annualized Return: {annualized_return(mean_pf, initial_cash):.2f}%")
print(f"→ Buy & Hold Return:      {annualized_return(bh_final, initial_cash):.2f}%")

# === Histogram ===
plt.figure(figsize=(6, 4))
plt.hist(final_pf, bins=10, edgecolor='k', alpha=0.7)
plt.axvline(bh_final, color='r', linestyle='--', linewidth=2, label='Buy & Hold')
plt.title("MLP + Features: Final Portfolio Distribution (Test Data)")
plt.xlabel("Final Portfolio Value")
plt.ylabel("Count")
plt.legend()
plt.grid(True)
plt.tight_layout()
#plt.savefig("MLP_Features/UNSEEN_hist.png", dpi=600)
plt.show()

# === Median ± Std Dev plot ===
x_dates = bh_dates[state_dim - 1 : state_dim - 1 + max_len]
min_len = min(len(x_dates), len(mean_curve), len(buy_hold_curve))
x_dates = x_dates[:min_len]
mean_curve = mean_curve[:min_len]
std_curve = std_curve[:min_len]
buy_hold_curve = buy_hold_curve[:min_len]

plt.figure(figsize=(10, 5))
plt.plot(x_dates, mean_curve, label="PPO Mean", linewidth=2)
plt.fill_between(x_dates, mean_curve - std_curve, mean_curve + std_curve,
                 color='skyblue', alpha=0.4, label='Std Dev')
plt.plot(x_dates, buy_hold_curve, 'r--', label=f'Buy & Hold = {bh_final:.2f}')
plt.title("MLP with Features: Test Set Portfolio Evaluation")
plt.xlabel("Date")
plt.ylabel("Portfolio Value")
plt.legend()
plt.grid(True)
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=2))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m"))
plt.gcf().autofmt_xdate()
plt.tight_layout()
#plt.savefig("MLP_Features/UNSEEN_PF_overtime.png", dpi=600)
plt.show()

"""
pd.DataFrame({"final_portfolio_value": final_pf}).to_csv("MLP_Features/ppo_final_portfolios_test.csv", index=False)
pd.DataFrame(ppo_trajectories).T.to_csv("MLP_Features/ppo_all_trajectories_test.csv", index=False)
print("✓ Saved final portfolio values → MLP_Features/ppo_final_portfolios_test.csv")
print("✓ Saved all portfolio trajectories → MLP_Features/ppo_all_trajectories_test.csv")
"""
